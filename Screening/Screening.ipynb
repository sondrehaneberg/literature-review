# %%
import pandas as pd
import numpy as np

# %%
# Set used to keep track of any skipped decisions (placed here to not be reset without purpose)
skipped = set()

# %% [markdown]
# # 1. Import data

# %% [markdown]
# ## 1.1 Scopus

# %%
scopus_df = pd.read_csv("Scopus.csv")
print(scopus_df.columns)
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Funding Texts', 'References', 'Editors', 'Publisher', 'Sponsors',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
clean_scopus_df = scopus_df[["DOI", "Title", "Abstract", "Author Keywords"]].copy()
clean_scopus_df.columns = ["DOI", "Title", "Abstract", "Keywords"]
clean_scopus_df["ID"] = np.where(pd.isna(clean_scopus_df["DOI"]), scopus_df["EID"], clean_scopus_df["DOI"])
clean_scopus_df = clean_scopus_df.set_index("ID")
clean_scopus_df["Origin"] = "Scopus"
clean_scopus_df.index.name = "ID"
clean_scopus_df
# Out:
#                                                          DOI  \
# ID
# 10.1007/978-3-031-99353-4_33    10.1007/978-3-031-99353-4_33
# 10.1007/978-981-96-6291-3_3      10.1007/978-981-96-6291-3_3
# 10.1016/j.renene.2025.124004    10.1016/j.renene.2025.124004
# 10.1016/j.eswa.2025.128676        10.1016/j.eswa.2025.128676
# 10.1038/s42003-025-07694-9        10.1038/s42003-025-07694-9
# ...                                                      ...
# 10.32473/flairs.v35i.130668      10.32473/flairs.v35i.130668
# 10.1007/s40888-021-00223-x        10.1007/s40888-021-00223-x
# 10.18653/v1/2021.semeval-1.87  10.18653/v1/2021.semeval-1.87
# 10.1016/j.chphi.2020.100005      10.1016/j.chphi.2020.100005
# 10.12816/0051162                            10.12816/0051162
#
#                                                                            Title  \
# ID
# 10.1007/978-3-031-99353-4_33   Predicting Startup IPO: A Data-Driven Approach...
# 10.1007/978-981-96-6291-3_3    Stock Price Prediction Using Univariate and Mu...
# 10.1016/j.renene.2025.124004   Probabilistic prediction of photovoltaic power...
# 10.1016/j.eswa.2025.128676     In the beginning was the Word: LLM-VaR and LLM-ES
# 10.1038/s42003-025-07694-9     RNA-protein interaction prediction using netwo...
# ...                                                                          ...
# 10.32473/flairs.v35i.130668    A Comparison of House Price Classification wit...
# 10.1007/s40888-021-00223-x            Robots and employment: evidence from Italy
# 10.18653/v1/2021.semeval-1.87  cs60075 team2 at SemEval-2021 Task 1: Lexical ...
# 10.1016/j.chphi.2020.100005    Theoretical prediction of decomposition temper...
# 10.12816/0051162               The estimation and the fulfi llment scenarios ...
#
#                                                                         Abstract  \
# ID
# 10.1007/978-3-031-99353-4_33   The startup ecosystem is constantly evolving, ...
# 10.1007/978-981-96-6291-3_3    In this study, we propose a hybrid approach th...
# 10.1016/j.renene.2025.124004   Accurate weekly probabilistic forecasting of p...
# 10.1016/j.eswa.2025.128676     This study introduces LLM-VaR and LLM-ES, nove...
# 10.1038/s42003-025-07694-9     Accurate computational determination of RNA-pr...
# ...                                                                          ...
# 10.32473/flairs.v35i.130668    Purchasing a home is one of the largest invest...
# 10.1007/s40888-021-00223-x     Increased robot diffusion has raised concerns ...
# 10.18653/v1/2021.semeval-1.87  This paper describes the performance of the te...
# 10.1016/j.chphi.2020.100005    With the approaching exhaustion of shallow-gro...
# 10.12816/0051162               This study aims to test the role of Sharia in ...
#
#                                                                         Keywords  \
# ID
# 10.1007/978-3-031-99353-4_33   Api; Cosine Similarity; Explainable Ai; Featur...
# 10.1007/978-981-96-6291-3_3    Large Language Models (llm); Multivariate Anal...
# 10.1016/j.renene.2025.124004   Deepseekr1; Fine-tuning Adapter; Large Languag...
# 10.1016/j.eswa.2025.128676     Expected Shortfall; Gpt; Large Language Models...
# 10.1038/s42003-025-07694-9     Rna; Rna; Rna, Viral; Rna-binding Proteins; Pr...
# ...                                                                          ...
# 10.32473/flairs.v35i.130668    Economics; Houses; Text Processing; House's Pr...
# 10.1007/s40888-021-00223-x     Automation; Employment; Local Labour Markets; ...
# 10.18653/v1/2021.semeval-1.87  Correlation Methods; Semantics; Complex Datase...
# 10.1016/j.chphi.2020.100005    Conversion Temperature; Decomposition Temperat...
# 10.12816/0051162               Employee Engagement; Human Capital; Human Reso...
#
#                                Origin
# ID
# 10.1007/978-3-031-99353-4_33   Scopus
# 10.1007/978-981-96-6291-3_3    Scopus
# 10.1016/j.renene.2025.124004   Scopus
# 10.1016/j.eswa.2025.128676     Scopus
# 10.1038/s42003-025-07694-9     Scopus
# ...                               ...
# 10.32473/flairs.v35i.130668    Scopus
# 10.1007/s40888-021-00223-x     Scopus
# 10.18653/v1/2021.semeval-1.87  Scopus
# 10.1016/j.chphi.2020.100005    Scopus
# 10.12816/0051162               Scopus
#
# [220 rows x 5 columns]

# %% [markdown]
# ## 1.2 Web of Science

# %%
WoS_df = pd.read_csv("WoS.txt", sep="\t", dtype=str, engine="python", encoding="utf-8")

WoS_df
# Out:
#     PT                                                 AU   BA  \
# 0    J               Chen, R; Jiang, HQ; Guo, TY; Fan, CY  NaN
# 1    J                                            Zhou, Y  NaN
# 2    J                              Ma, F; Lyu, Z; Li, HB  NaN
# 3    J                                Xiao, F; Wang, XTXT  NaN
# 4    C       Lee, G; Yu, WC; Shin, KJ; Cheng, W; Chen, HF  NaN
# ..  ..                                                ...  ...
# 151  J  Kocon, J; Cichecki, I; Kaszyca, O; Kochanek, M...  NaN
# 152  J      Shi, J; Lee, M; Girish, VG; Xiao, GY; Lee, CK  NaN
# 153  J  Odabashian, R; Bastin, D; Jones, G; Manzoor, M...  NaN
# 154  J  Guariso, D; Adewoyin, R; Aguilar, GR; Guerrero...  NaN
# 155  J  Li, CX; Zhao, YN; Bai, Y; Zhao, BQ; Tola, YO; ...  NaN
#
#                                BE   GP  \
# 0                             NaN  NaN
# 1                             NaN  NaN
# 2                             NaN  NaN
# 3                             NaN  NaN
# 4    Walsh, T; Shah, J; Kolter, Z  NaN
# ..                            ...  ...
# 151                           NaN  NaN
# 152                           NaN  NaN
# 153                           NaN  NaN
# 154                           NaN  NaN
# 155                           NaN  NaN
#
#                                                     AF   BF   CA  \
# 0    Chen, Rui; Jiang, Haiqi; Guo, Tingyu; Fan, Che...  NaN  NaN
# 1                                             Zhou, Yi  NaN  NaN
# 2                   Ma, Feng; Lyu, Zhichong; Li, Haibo  NaN  NaN
# 3                     Xiao, Feng; Wang, X. T. XiaoTian  NaN  NaN
# 4    Lee, Geon; Yu, Wenchao; Shin, Kijung; Cheng, W...  NaN  NaN
# ..                                                 ...  ...  ...
# 151  Kocon, Jan; Cichecki, Igor; Kaszyca, Oliwier; ...  NaN  NaN
# 152  Shi, Ji; Lee, Minwoo; Girish, V. G.; Xiao, Gua...  NaN  NaN
# 153  Odabashian, Roupen; Bastin, Donald; Jones, Geo...  NaN  NaN
# 154  Guariso, Daniele; Adewoyin, Rilwan; Aguilar, G...  NaN  NaN
# 155  Li, Caixia; Zhao, Yina; Bai, Yang; Zhao, Baoqu...  NaN  NaN
#
#                                                     TI  \
# 0    Can Large Language Models forecast carbon pric...
# 1    Using Generative AI to predict the weather imp...
# 2         Can ChatGPT predict Chinese equity premiums?
# 3    Evaluating the ability of large Language model...
# 4    TimeCAP: Learning to Contextualize, Augment, a...
# ..                                                 ...
# 151        ChatGPT: Jack of all trades, master of none
# 152  Embracing the ChatGPT revolution: unlocking ne...
# 153  Assessment of ChatGPT-3.5's Knowledge in Oncol...
# 154  A generalized LLMs framework to support public...
# 155  Unveiling the Potential of Large Language Mode...
#
#                                                     SO  ...  \
# 0       RESEARCH IN INTERNATIONAL BUSINESS AND FINANCE  ...
# 1                   JOURNAL OF ALGEBRAIC COMBINATORICS  ...
# 2                             FINANCE RESEARCH LETTERS  ...
# 3                                   SCIENTIFIC REPORTS  ...
# 4    THIRTY-NINTH AAAI CONFERENCE ON ARTIFICIAL INT...  ...
# ..                                                 ...  ...
# 151                                 INFORMATION FUSION  ...
# 152      JOURNAL OF HOSPITALITY AND TOURISM TECHNOLOGY  ...
# 153                                            JMIR AI  ...
# 154                ARTIFICIAL INTELLIGENCE IN MEDICINE  ...
# 155               JOURNAL OF MEDICAL INTERNET RESEARCH  ...
#
#                                                     WC  \
# 0                                    Business, Finance
# 1                                          Mathematics
# 2                                    Business, Finance
# 3                           Multidisciplinary Sciences
# 4    Computer Science, Artificial Intelligence; Com...
# ..                                                 ...
# 151  Computer Science, Artificial Intelligence; Com...
# 152              Hospitality, Leisure, Sport & Tourism
# 153  Health Care Sciences & Services; Medical Infor...
# 154  Computer Science, Artificial Intelligence; Eng...
# 155  Health Care Sciences & Services; Medical Infor...
#
#                                                     WE  \
# 0                 Social Science Citation Index (SSCI)
# 1       Science Citation Index Expanded (SCI-EXPANDED)
# 2                 Social Science Citation Index (SSCI)
# 3       Science Citation Index Expanded (SCI-EXPANDED)
# 4    Conference Proceedings Citation Index - Scienc...
# ..                                                 ...
# 151     Science Citation Index Expanded (SCI-EXPANDED)
# 152               Social Science Citation Index (SSCI)
# 153             Emerging Sources Citation Index (ESCI)
# 154     Science Citation Index Expanded (SCI-EXPANDED)
# 155     Science Citation Index Expanded (SCI-EXPANDED)
#
#                                                     SC     GA        PM  \
# 0                                 Business & Economics  2TX3E       NaN
# 1                                          Mathematics  5SR6T       NaN
# 2                                 Business & Economics  D2O6R       NaN
# 3                  Science & Technology - Other Topics  7DY7U  40897780
# 4                                     Computer Science  BY6EV       NaN
# ..                                                 ...    ...       ...
# 151                                   Computer Science  L7RA5       NaN
# 152                     Social Sciences - Other Topics  QD9C8       NaN
# 153  Health Care Sciences & Services; Medical Infor...  P0H0I  38875575
# 154  Computer Science; Engineering; Medical Informa...  5GI1Z  40690805
# 155  Health Care Sciences & Services; Medical Infor...  2BS6C  40239198
#
#                         OA   HC   HP          DA                   UT
# 0                      NaN  NaN  NaN  2025-10-02  WOS:001491215500001
# 1                      NaN  NaN  NaN  2025-10-02  WOS:001528297000001
# 2                      NaN  NaN  NaN  2025-10-02  WOS:001294636400001
# 3                     gold  NaN  NaN  2025-10-02  WOS:001568749500021
# 4                     gold  NaN  NaN  2025-10-02  WOS:001477527200064
# ..                     ...  ...  ...         ...                  ...
# 151                 hybrid  NaN  NaN  2025-10-02  WOS:001025183100001
# 152                    NaN  NaN  NaN  2025-10-02  WOS:001198820600001
# 153  Green Submitted, gold  NaN  NaN  2025-10-02  WOS:001374817300001
# 154                    NaN  NaN  NaN  2025-10-02  WOS:001535014800001
# 155  gold, Green Submitted  NaN  NaN  2025-10-02  WOS:001478857800005
#
# [156 rows x 71 columns]

# %%
clean_WoS_df = WoS_df[["UT", "TI", "AB", "DI", "DE"]].set_index("UT")
clean_WoS_df.columns = ["Title", "Abstract", "DOI", "Keywords"]
clean_scopus_df["ID"] = np.where(pd.isna(clean_scopus_df["DOI"]), scopus_df["EID"], clean_scopus_df["DOI"])
clean_scopus_df = clean_scopus_df.set_index("ID")
clean_WoS_df["Origin"] = "WoS"
clean_WoS_df.index.name = "ID"

clean_WoS_df
# Out:
#                                                                  Title  \
# ID
# WOS:001491215500001  Can Large Language Models forecast carbon pric...
# WOS:001528297000001  Using Generative AI to predict the weather imp...
# WOS:001294636400001       Can ChatGPT predict Chinese equity premiums?
# WOS:001568749500021  Evaluating the ability of large Language model...
# WOS:001477527200064  TimeCAP: Learning to Contextualize, Augment, a...
# ...                                                                ...
# WOS:001025183100001        ChatGPT: Jack of all trades, master of none
# WOS:001198820600001  Embracing the ChatGPT revolution: unlocking ne...
# WOS:001374817300001  Assessment of ChatGPT-3.5's Knowledge in Oncol...
# WOS:001535014800001  A generalized LLMs framework to support public...
# WOS:001478857800005  Unveiling the Potential of Large Language Mode...
#
#                                                               Abstract  \
# ID
# WOS:001491215500001  This paper investigates the impact of Large La...
# WOS:001528297000001  This study explores the use of Generative AI, ...
# WOS:001294636400001  Leveraging over 1.86 million news headlines, w...
# WOS:001568749500021  Recent advances in large language models (LLMs...
# WOS:001477527200064  Time series data is essential in various appli...
# ...                                                                ...
# WOS:001025183100001  OpenAI has released the Chat Generative Pre-tr...
# WOS:001198820600001  Purpose - This study aims to investigate touri...
# WOS:001374817300001  Background: ChatGPT (Open AI) is a state-of-th...
# WOS:001535014800001  As a systemic problem, public health cannot be...
# WOS:001478857800005  Background: Chronic diseases are a major globa...
#
#                                               DOI  \
# ID
# WOS:001491215500001   10.1016/j.ribaf.2025.102951
# WOS:001528297000001    10.1007/s11156-025-01437-x
# WOS:001294636400001     10.1016/j.frl.2024.105631
# WOS:001568749500021    10.1038/s41598-025-17188-7
# WOS:001477527200064                           NaN
# ...                                           ...
# WOS:001025183100001  10.1016/j.inffus.2023.101861
# WOS:001198820600001     10.1108/JHTT-07-2023-0203
# WOS:001374817300001                 10.2196/50442
# WOS:001535014800001  10.1016/j.artmed.2025.103203
# WOS:001478857800005                 10.2196/70535
#
#                                                               Keywords Origin
# ID
# WOS:001491215500001  Carbon Price Forecasting; Large Language Model...    WoS
# WOS:001528297000001  Weather risk; Stock returns; Generative AI; Ch...    WoS
# WOS:001294636400001  Large language model; ChatGPT; Chinese equity ...    WoS
# WOS:001568749500021  Generative AI; Social decision-making; Framing...    WoS
# WOS:001477527200064                                                NaN    WoS
# ...                                                                ...    ...
# WOS:001025183100001  ChatGPT; GPT-4; Natural language processing (N...    WoS
# WOS:001198820600001  ChatGPT; Generative AI; Information; Perceived...    WoS
# WOS:001374817300001  artificial intelligence; ChatGPT-3.5; language...    WoS
# WOS:001535014800001  Large Language Models; Public health financing...    WoS
# WOS:001478857800005  artificial intelligence; chronic disease; heal...    WoS
#
# [156 rows x 5 columns]

# %% [markdown]
# ## 1.3 IEEE

# %% [markdown]
# ## 1.4 ProQuest

# %% [markdown]
# # 2. Merge and Clean data

# %%
clean_df = pd.concat([clean_scopus_df, clean_WoS_df])
clean_df
# Out:
#                                                        DOI  \
# ID
# 10.1007/978-3-031-99353-4_33  10.1007/978-3-031-99353-4_33
# 10.1007/978-981-96-6291-3_3    10.1007/978-981-96-6291-3_3
# 10.1016/j.renene.2025.124004  10.1016/j.renene.2025.124004
# 10.1016/j.eswa.2025.128676      10.1016/j.eswa.2025.128676
# 10.1038/s42003-025-07694-9      10.1038/s42003-025-07694-9
# ...                                                    ...
# WOS:001025183100001           10.1016/j.inffus.2023.101861
# WOS:001198820600001              10.1108/JHTT-07-2023-0203
# WOS:001374817300001                          10.2196/50442
# WOS:001535014800001           10.1016/j.artmed.2025.103203
# WOS:001478857800005                          10.2196/70535
#
#                                                                           Title  \
# ID
# 10.1007/978-3-031-99353-4_33  Predicting Startup IPO: A Data-Driven Approach...
# 10.1007/978-981-96-6291-3_3   Stock Price Prediction Using Univariate and Mu...
# 10.1016/j.renene.2025.124004  Probabilistic prediction of photovoltaic power...
# 10.1016/j.eswa.2025.128676    In the beginning was the Word: LLM-VaR and LLM-ES
# 10.1038/s42003-025-07694-9    RNA-protein interaction prediction using netwo...
# ...                                                                         ...
# WOS:001025183100001                 ChatGPT: Jack of all trades, master of none
# WOS:001198820600001           Embracing the ChatGPT revolution: unlocking ne...
# WOS:001374817300001           Assessment of ChatGPT-3.5's Knowledge in Oncol...
# WOS:001535014800001           A generalized LLMs framework to support public...
# WOS:001478857800005           Unveiling the Potential of Large Language Mode...
#
#                                                                        Abstract  \
# ID
# 10.1007/978-3-031-99353-4_33  The startup ecosystem is constantly evolving, ...
# 10.1007/978-981-96-6291-3_3   In this study, we propose a hybrid approach th...
# 10.1016/j.renene.2025.124004  Accurate weekly probabilistic forecasting of p...
# 10.1016/j.eswa.2025.128676    This study introduces LLM-VaR and LLM-ES, nove...
# 10.1038/s42003-025-07694-9    Accurate computational determination of RNA-pr...
# ...                                                                         ...
# WOS:001025183100001           OpenAI has released the Chat Generative Pre-tr...
# WOS:001198820600001           Purpose - This study aims to investigate touri...
# WOS:001374817300001           Background: ChatGPT (Open AI) is a state-of-th...
# WOS:001535014800001           As a systemic problem, public health cannot be...
# WOS:001478857800005           Background: Chronic diseases are a major globa...
#
#                                                                        Keywords  \
# ID
# 10.1007/978-3-031-99353-4_33  Api; Cosine Similarity; Explainable Ai; Featur...
# 10.1007/978-981-96-6291-3_3   Large Language Models (llm); Multivariate Anal...
# 10.1016/j.renene.2025.124004  Deepseekr1; Fine-tuning Adapter; Large Languag...
# 10.1016/j.eswa.2025.128676    Expected Shortfall; Gpt; Large Language Models...
# 10.1038/s42003-025-07694-9    Rna; Rna; Rna, Viral; Rna-binding Proteins; Pr...
# ...                                                                         ...
# WOS:001025183100001           ChatGPT; GPT-4; Natural language processing (N...
# WOS:001198820600001           ChatGPT; Generative AI; Information; Perceived...
# WOS:001374817300001           artificial intelligence; ChatGPT-3.5; language...
# WOS:001535014800001           Large Language Models; Public health financing...
# WOS:001478857800005           artificial intelligence; chronic disease; heal...
#
#                               Origin
# ID
# 10.1007/978-3-031-99353-4_33  Scopus
# 10.1007/978-981-96-6291-3_3   Scopus
# 10.1016/j.renene.2025.124004  Scopus
# 10.1016/j.eswa.2025.128676    Scopus
# 10.1038/s42003-025-07694-9    Scopus
# ...                              ...
# WOS:001025183100001              WoS
# WOS:001198820600001              WoS
# WOS:001374817300001              WoS
# WOS:001535014800001              WoS
# WOS:001478857800005              WoS
#
# [376 rows x 5 columns]

# %%
# Temporarily reset index
clean_df = clean_df.reset_index()

# Separate rows with NaN in 'DOI'
nan_rows = clean_df[clean_df['DOI'].isna()]

# Process rows where 'DOI' is not NaN
non_nan_rows = clean_df[clean_df['DOI'].notna()].copy()

# Normalize DOI
non_nan_rows["DOI"] = non_nan_rows["DOI"].str.lower()
non_nan_rows["DOI"] = non_nan_rows["DOI"].str.replace("https://doi.org/", "", regex=False)

# Drop duplicates based on DOI
non_nan_rows = non_nan_rows.drop_duplicates(subset=["DOI"], keep='first')

# Concatenate the untouched NaN rows back into the DataFrame
clean_df = pd.concat([non_nan_rows, nan_rows], ignore_index=True)

# Display the result
clean_df
# Out:
#                                ID                           DOI  \
# 0    10.1007/978-3-031-99353-4_33  10.1007/978-3-031-99353-4_33
# 1     10.1007/978-981-96-6291-3_3   10.1007/978-981-96-6291-3_3
# 2    10.1016/j.renene.2025.124004  10.1016/j.renene.2025.124004
# 3      10.1016/j.eswa.2025.128676    10.1016/j.eswa.2025.128676
# 4      10.1038/s42003-025-07694-9    10.1038/s42003-025-07694-9
# ..                            ...                           ...
# 265           WOS:000889371704042                           NaN
# 266           WOS:001181085100165                           NaN
# 267           WOS:001347142807059                           NaN
# 268           WOS:001371932507019                           NaN
# 269           WOS:001301787507073                           NaN
#
#                                                  Title  \
# 0    Predicting Startup IPO: A Data-Driven Approach...
# 1    Stock Price Prediction Using Univariate and Mu...
# 2    Probabilistic prediction of photovoltaic power...
# 3    In the beginning was the Word: LLM-VaR and LLM-ES
# 4    RNA-protein interaction prediction using netwo...
# ..                                                 ...
# 265  CEPOC: The Cambridge Exams Publishing Open Clo...
# 266  Performance and Risk Trade-offs for Multi-word...
# 267  RisQNet: Rescuing SMEs from Financial Shocks w...
# 268  R-U-SURE? Uncertainty-Aware Code Suggestions B...
# 269  Quantum Feature Embeddings for Graph Neural Ne...
#
#                                               Abstract  \
# 0    The startup ecosystem is constantly evolving, ...
# 1    In this study, we propose a hybrid approach th...
# 2    Accurate weekly probabilistic forecasting of p...
# 3    This study introduces LLM-VaR and LLM-ES, nove...
# 4    Accurate computational determination of RNA-pr...
# ..                                                 ...
# 265  Open cloze tests are a standard type of exerci...
# 266  Large Language Models such as GPT-3 are well-s...
# 267  In the face of economic downturns, Small and M...
# 268  Large language models show impressive results ...
# 269  Quantum computing offers a promising avenue to...
#
#                                               Keywords  Origin
# 0    Api; Cosine Similarity; Explainable Ai; Featur...  Scopus
# 1    Large Language Models (llm); Multivariate Anal...  Scopus
# 2    Deepseekr1; Fine-tuning Adapter; Large Languag...  Scopus
# 3    Expected Shortfall; Gpt; Large Language Models...  Scopus
# 4    Rna; Rna; Rna, Viral; Rna-binding Proteins; Pr...  Scopus
# ..                                                 ...     ...
# 265  open cloze; blank-filling; language learning; ...     WoS
# 266                                                NaN     WoS
# 267                                                NaN     WoS
# 268                                                NaN     WoS
# 269                     Quantum Machine Learning; GNNs     WoS
#
# [270 rows x 6 columns]

# %%
# Show title dupes
clean_df[clean_df["Title"].duplicated(keep=False)].sort_values("Title")
# Out:
#                                       ID                                  DOI  \
# 225                  2-s2.0-105007166117                                  NaN
# 226                  2-s2.0-105007143427                                  NaN
# 216                   2-s2.0-85212494941                                  NaN
# 217                   2-s2.0-85212253172                                  NaN
# 224                  2-s2.0-105007761709                                  NaN
# 223                  2-s2.0-105007848472                                  NaN
# 169  10.18653/v1/2023.findings-emnlp.490  10.18653/v1/2023.findings-emnlp.490
# 257                  WOS:001279591707033                                  NaN
# 265                  WOS:000889371704042                                  NaN
# 249                   2-s2.0-85144347623                                  NaN
# 262                  WOS:001503391700001                                  NaN
# 83          10.14569/IJACSA.2025.0160402         10.14569/ijacsa.2025.0160402
# 239                   2-s2.0-85180626542                                  NaN
# 238                   2-s2.0-85180631189                                  NaN
# 240                   2-s2.0-85180625398                                  NaN
# 258                  WOS:001226352800025                                  NaN
# 246                   2-s2.0-85188265330                                  NaN
# 254                  WOS:001511618600130                                  NaN
# 140  10.18653/v1/2024.findings-naacl.130  10.18653/v1/2024.findings-naacl.130
# 252                  WOS:001424958800096                                  NaN
# 231                   2-s2.0-85216409938                                  NaN
# 269                  WOS:001301787507073                                  NaN
# 237                   2-s2.0-85184348532                                  NaN
# 268                  WOS:001371932507019                                  NaN
# 248                   2-s2.0-85174411111                                  NaN
# 232                   2-s2.0-85204303359                                  NaN
# 267                  WOS:001347142807059                                  NaN
# 260                  WOS:001477508100094                                  NaN
# 39             10.1609/aaai.v39i21.34447            10.1609/aaai.v39i21.34447
# 244                   2-s2.0-85196140051                                  NaN
# 256                  WOS:001347141700005                                  NaN
# 251                  WOS:001477527200064                                  NaN
# 38             10.1609/aaai.v39i17.33989            10.1609/aaai.v39i17.33989
# 261                  WOS:001502658900017                                  NaN
# 82                10.3905/jpm.2025.1.710               10.3905/jpm.2025.1.710
# 177        10.18653/v1/2021.semeval-1.87        10.18653/v1/2021.semeval-1.87
# 259                  WOS:001361894000087                                  NaN
#
#                                                  Title  \
# 225  12th International Conference on HCI in Busine...
# 226  12th International Conference on HCI in Busine...
# 216  26th International Conference on Information I...
# 217  26th International Conference on Information I...
# 224  7th International Conference on Adaptive Instr...
# 223  7th International Conference on Adaptive Instr...
# 169  A Comprehensive Evaluation of Large Language M...
# 257  A Comprehensive Evaluation of Large Language M...
# 265  CEPOC: The Cambridge Exams Publishing Open Clo...
# 249  CEPOC: The Cambridge Exams Publishing Open Clo...
# 262  Comparing Vision-Instruct LLMs, Vision-Based D...
# 83   Comparing Vision-Instruct LLMs, Vision-Based D...
# 239  IFIP WG 8.6 International Working Conference o...
# 238  IFIP WG 8.6 International Working Conference o...
# 240  IFIP WG 8.6 International Working Conference o...
# 258  Language Models Don't Always Say What They Thi...
# 246  Language Models Don't Always Say What They Thi...
# 254  Large Language Models Sensitivity to The Order...
# 140  Large Language Models Sensitivity to The Order...
# 252  Prediction of Foreign Exchange Rates by a Larg...
# 231  Prediction of Foreign Exchange Rates by a Larg...
# 269  Quantum Feature Embeddings for Graph Neural Ne...
# 237  Quantum Feature Embeddings for Graph Neural Ne...
# 268  R-U-SURE? Uncertainty-Aware Code Suggestions B...
# 248  R-U-SURE? Uncertainty-Aware Code Suggestions B...
# 232  RisQNet: Rescuing SMEs from Financial Shocks w...
# 267  RisQNet: Rescuing SMEs from Financial Shocks w...
# 260  STEM-LTS: Integrating Semantic-Temporal Dynami...
# 39   STEM-LTS: Integrating Semantic-Temporal Dynami...
# 244  Self-Evaluation Improves Selective Generation ...
# 256  Self-Evaluation Improves Selective Generation ...
# 251  TimeCAP: Learning to Contextualize, Augment, a...
# 38   TimeCAP: Learning to Contextualize, Augment, a...
# 261  Using Large Language Models to Estimate Novel ...
# 82   Using Large Language Models to Estimate Novel ...
# 177  cs60075 team2 at SemEval-2021 Task 1: Lexical ...
# 259  cs60075 team2 at SemEval-2021 Task 1: Lexical ...
#
#                                               Abstract  \
# 225  The proceedings contain 41 papers. The special...
# 226  The proceedings contain 41 papers. The special...
# 216  The proceedings contain 52 papers. The special...
# 217  The proceedings contain 52 papers. The special...
# 224  The proceedings contain 40 papers. The special...
# 223  The proceedings contain 40 papers. The special...
# 169  Large language models (LLMs) have demonstrated...
# 257  Large language models (LLMs) have demonstrated...
# 265  Open cloze tests are a standard type of exerci...
# 249  Open cloze tests are a standard type of exerci...
# 262  This research conducts a comparative study of ...
# 83   This research conducts a comparative study of ...
# 239  The proceedings contain 112 papers. The specia...
# 238  The proceedings contain 112 papers. The specia...
# 240  The proceedings contain 112 papers. The specia...
# 258  Large Language Models (LLMs) can achieve stron...
# 246  Large Language Models (LLMs) can achieve stron...
# 254  Large Language Models (LLMs) have demonstrated...
# 140  Large Language Models (LLMs) have demonstrated...
# 252  This paper proposes a prompt-based method util...
# 231  This paper proposes a prompt-based method util...
# 269  Quantum computing offers a promising avenue to...
# 237  Quantum computing offers a promising avenue to...
# 268  Large language models show impressive results ...
# 248  Large language models show impressive results ...
# 232  In the face of economic downturns, Small and M...
# 267  In the face of economic downturns, Small and M...
# 260  Time series forecasting plays a crucial role i...
# 39   Time series forecasting plays a crucial role i...
# 244  Safe deployment of large language models (LLMs...
# 256  Safe deployment of large language models (LLMs...
# 251  Time series data is essential in various appli...
# 38   Time series data is essential in various appli...
# 261  This article presents an integrated framework ...
# 82   This article presents an integrated framework ...
# 177  This paper describes the performance of the te...
# 259  This paper describes the performance of the te...
#
#                                               Keywords  Origin
# 225                                                NaN  Scopus
# 226                                                NaN  Scopus
# 216                                                NaN  Scopus
# 217                                                NaN  Scopus
# 224                                                NaN  Scopus
# 223                                                NaN  Scopus
# 169  Computational Linguistics; Domain Knowledge; C...  Scopus
# 257                                                NaN     WoS
# 265  open cloze; blank-filling; language learning; ...     WoS
# 249  Blank-filling; Cambridge Examinations; Languag...  Scopus
# 262  Convolutional Neural Network (CNN); Large Lan-...     WoS
# 83   Convolutional Neural Network (cnn); Large Lang...  Scopus
# 239                                                NaN  Scopus
# 238                                                NaN  Scopus
# 240                                                NaN  Scopus
# 258                                                NaN     WoS
# 246  Bias Modeling; Language Model; Model Inputs; M...  Scopus
# 254                                                NaN     WoS
# 140  Benchmarking; Computational Linguistics; Langu...  Scopus
# 252  Large language model; Foreign exchange rate; F...     WoS
# 231  Finance; Foreign Exchange Rate; Large Language...  Scopus
# 269                     Quantum Machine Learning; GNNs     WoS
# 237  Gnns; Quantum Machine Learning; Benchmarking; ...  Scopus
# 268                                                NaN     WoS
# 248  Machine Learning; Open Source Software; Progra...  Scopus
# 232  Artificial Intelligence; Economic And Social E...  Scopus
# 267                                                NaN     WoS
# 260                                                NaN     WoS
# 39   Time Series Analysis; Interpretability; Langua...  Scopus
# 244  Benchmarking; Computational Linguistics; Quali...  Scopus
# 256                                                NaN     WoS
# 251                                                NaN     WoS
# 38   Contextual Information; Contextualize; Event P...  Scopus
# 261                                                NaN     WoS
# 82                                                 NaN  Scopus
# 177  Correlation Methods; Semantics; Complex Datase...  Scopus
# 259                                                NaN     WoS

# %%
# Drop duplicates based on title
clean_df = clean_df.groupby(['Title'], as_index=False).first()
clean_df = clean_df.copy()
clean_df
# Out:
#                                                  Title  \
# 0    12th International Conference on HCI in Busine...
# 1    14th Symposium on Languages, Applications and ...
# 2    18th International Conference on Information T...
# 3    2023 IEEE International Conference on Enabling...
# 4    2024 6th International Conference on Machine L...
# ..                                                 ...
# 246  Using Large Language Models to Estimate Novel ...
# 247  Utilizing Text-Generative AI for Creating Oral...
# 248  Zero-Shot Classification of Art with Large Lan...
# 249  Zero-Shot Time Series Forecasting of the Onlin...
# 250  cs60075 team2 at SemEval-2021 Task 1: Lexical ...
#
#                                       ID                                  DOI  \
# 0                    2-s2.0-105007166117                                 None
# 1                    2-s2.0-105013137151                                 None
# 2                    2-s2.0-105009402610                                 None
# 3                     2-s2.0-85190369483                                 None
# 4                     2-s2.0-85216976361                                 None
# ..                                   ...                                  ...
# 246               10.3905/jpm.2025.1.710               10.3905/jpm.2025.1.710
# 247            10.1177/10534512241235896            10.1177/10534512241235896
# 248          10.1109/ACCESS.2025.3532995          10.1109/access.2025.3532995
# 249  10.1109/ITC-CSCC66376.2025.11137629  10.1109/itc-cscc66376.2025.11137629
# 250        10.18653/v1/2021.semeval-1.87        10.18653/v1/2021.semeval-1.87
#
#                                               Abstract  \
# 0    The proceedings contain 41 papers. The special...
# 1    The proceedings contain 13 papers. The topics ...
# 2    The proceedings contain 59 papers. The special...
# 3    The proceedings contain 36 papers. The topics ...
# 4    The proceedings contain 57 papers. The topics ...
# ..                                                 ...
# 246  This article presents an integrated framework ...
# 247  Oral reading fluency probes are essential for ...
# 248  Art has become an important new investment veh...
# 249  This study introduces a zero-shot forecasting ...
# 250  This paper describes the performance of the te...
#
#                                               Keywords  Origin
# 0                                                 None  Scopus
# 1                                                 None  Scopus
# 2                                                 None  Scopus
# 3                                                 None  Scopus
# 4                                                 None  Scopus
# ..                                                 ...     ...
# 246                                               None  Scopus
# 247  Academic Intervention; Artificial Intelligence...  Scopus
# 248  Art; Auction Price; Chatgpt; Classification; D...  Scopus
# 249  Online Gig Economy; Online Labor Index; Pre-tr...  Scopus
# 250  Correlation Methods; Semantics; Complex Datase...  Scopus
#
# [251 rows x 6 columns]

# %%
# Set ID as index again
clean_df = clean_df.set_index("ID")
clean_df
# Out:
#                                                                                  Title  \
# ID
# 2-s2.0-105007166117                  12th International Conference on HCI in Busine...
# 2-s2.0-105013137151                  14th Symposium on Languages, Applications and ...
# 2-s2.0-105009402610                  18th International Conference on Information T...
# 2-s2.0-85190369483                   2023 IEEE International Conference on Enabling...
# 2-s2.0-85216976361                   2024 6th International Conference on Machine L...
# ...                                                                                ...
# 10.3905/jpm.2025.1.710               Using Large Language Models to Estimate Novel ...
# 10.1177/10534512241235896            Utilizing Text-Generative AI for Creating Oral...
# 10.1109/ACCESS.2025.3532995          Zero-Shot Classification of Art with Large Lan...
# 10.1109/ITC-CSCC66376.2025.11137629  Zero-Shot Time Series Forecasting of the Onlin...
# 10.18653/v1/2021.semeval-1.87        cs60075 team2 at SemEval-2021 Task 1: Lexical ...
#
#                                                                      DOI  \
# ID
# 2-s2.0-105007166117                                                 None
# 2-s2.0-105013137151                                                 None
# 2-s2.0-105009402610                                                 None
# 2-s2.0-85190369483                                                  None
# 2-s2.0-85216976361                                                  None
# ...                                                                  ...
# 10.3905/jpm.2025.1.710                            10.3905/jpm.2025.1.710
# 10.1177/10534512241235896                      10.1177/10534512241235896
# 10.1109/ACCESS.2025.3532995                  10.1109/access.2025.3532995
# 10.1109/ITC-CSCC66376.2025.11137629  10.1109/itc-cscc66376.2025.11137629
# 10.18653/v1/2021.semeval-1.87              10.18653/v1/2021.semeval-1.87
#
#                                                                               Abstract  \
# ID
# 2-s2.0-105007166117                  The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                  The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                  The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                   The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                   The proceedings contain 57 papers. The topics ...
# ...                                                                                ...
# 10.3905/jpm.2025.1.710               This article presents an integrated framework ...
# 10.1177/10534512241235896            Oral reading fluency probes are essential for ...
# 10.1109/ACCESS.2025.3532995          Art has become an important new investment veh...
# 10.1109/ITC-CSCC66376.2025.11137629  This study introduces a zero-shot forecasting ...
# 10.18653/v1/2021.semeval-1.87        This paper describes the performance of the te...
#
#                                                                               Keywords  \
# ID
# 2-s2.0-105007166117                                                               None
# 2-s2.0-105013137151                                                               None
# 2-s2.0-105009402610                                                               None
# 2-s2.0-85190369483                                                                None
# 2-s2.0-85216976361                                                                None
# ...                                                                                ...
# 10.3905/jpm.2025.1.710                                                            None
# 10.1177/10534512241235896            Academic Intervention; Artificial Intelligence...
# 10.1109/ACCESS.2025.3532995          Art; Auction Price; Chatgpt; Classification; D...
# 10.1109/ITC-CSCC66376.2025.11137629  Online Gig Economy; Online Labor Index; Pre-tr...
# 10.18653/v1/2021.semeval-1.87        Correlation Methods; Semantics; Complex Datase...
#
#                                      Origin
# ID
# 2-s2.0-105007166117                  Scopus
# 2-s2.0-105013137151                  Scopus
# 2-s2.0-105009402610                  Scopus
# 2-s2.0-85190369483                   Scopus
# 2-s2.0-85216976361                   Scopus
# ...                                     ...
# 10.3905/jpm.2025.1.710               Scopus
# 10.1177/10534512241235896            Scopus
# 10.1109/ACCESS.2025.3532995          Scopus
# 10.1109/ITC-CSCC66376.2025.11137629  Scopus
# 10.18653/v1/2021.semeval-1.87        Scopus
#
# [251 rows x 5 columns]

# %%
# Save initial screening as csv file
clean_df.to_csv("initial_screening.csv")

# %% [markdown]
# # 3. GPT Assessment

# %%
# Load previous assessments
gpt_response_df = pd.read_csv("gpt.csv", index_col=0)
gpt_response_df
# Out:
#                                                                                  Summary  \
# ID
# 2-s2.0-105007166117                    The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                    The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                    The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                     The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                     The proceedings contain 57 papers. The topics ...
# 2-s2.0-85201236297                     The proceedings contain 98 papers. The topics ...
# 2-s2.0-105004809261                    The proceedings contain 11 papers. The topics ...
# 2-s2.0-85212494941                     The proceedings contain 52 papers. The special...
# 2-s2.0-105007848472                    The proceedings contain 40 papers. The special...
# 2-s2.0-85176944442                     The proceedings contain 28 papers. The special...
# 10.1109/ISCMI63661.2024.10851487       Time series analysis of daily stock prices is ...
# 10.32473/flairs.v35i.130668            Purchasing a home is one of the largest invest...
# 10.18653/v1/2023.findings-emnlp.490    Large language models (LLMs) have demonstrated...
# 10.3390/jrfm18020099                   OpenAI’s new flagship model, ChatGPT-4o, relea...
# 10.1109/ACCESS.2024.3404862            In the face of rapidly increasing crime rates,...
# 10.1145/3637528.3671440                This tutorial offers a comprehensive guide on ...
# 10.1038/s41598-024-56740-9             English speakers use probabilistic phrases suc...
# 10.1016/j.ejor.2024.09.011             Investors are continuously seeking profitable ...
# 10.1016/j.artmed.2025.103203           As a systemic problem, public health cannot be...
# WOS:001225271800001                    In contemporary societies, the processes of tr...
# WOS:001421563000001                    Policy uncertainty is a potential source for r...
# 10.1063/5.0274031                      Large language models (LLMs) are reshaping the...
# 10.1007/978-3-031-55536-7              This book is a comprehensive guide to the use ...
# 10.1145/3677052.3698694                Investment Analysis is a cornerstone of the Fi...
# 10.1145/3707649                        Large language models (LLMs) match and sometim...
# 10.1016/j.frl.2025.106967              Financial risk prediction is crucial for inves...
# WOS:001540458000194                    Considering privacy concerns and real-time dem...
# WOS:001545134000011                    Large Language Models (LLM) empower many moder...
# 10.1145/3677052.3698681                Recent strategies for portfolio management oft...
# 10.1007/978-3-031-84371-6_3            In this study, we investigate the role of Gene...
# 10.1109/I2CT61223.2024.10543356        This paper presents the development of a groun...
# 10.1016/j.jer.2023.09.019              Road accidents have been progressively causing...
# 10.1109/ICSCNA58489.2023.10370253      Company' s brand perception majorly depends on...
# 10.3389/frai.2025.1609097              Large Language Models (LLMs) have significantl...
# 10.1001/jamasurg.2025.2154             Importance: Accurate prediction of surgical ca...
# 10.3390/e27060550                      This study examines the effectiveness of combi...
# WOS:001343416300025                    The abundance of tabular microdata constitutes...
# WOS:001374817300001                    Background: ChatGPT (Open AI) is a state-of-th...
# 10.1145/3652037.3652047                In accordance with the findings presented in [...
# 10.1145/3651655.3651658                As decentralized finance (DeFi) built on block...
# 10.16097/j.cnki.1009-6744.2025.04.014  Aiming at the problems that the high- level de...
# 10.1145/3677052.3698627                Predicting bankruptcy is crucial for managing ...
# 10.1145/3626772.3657882                GPT-4 demonstrates high accuracy in medical QA...
# 10.1109/CogSIMA61085.2024.10553755     Large language models (LLMs), like OpenAI’s Ch...
# 2-s2.0-105000518469                    We present a novel statistical framework for a...
# 10.3390/nu17071176                     Background/Objectives: Weight management is di...
# 10.22495/rgcv15i2p13                   The use of artificial intelligence (AI) in fin...
# 10.1093/rof/rfaf015                    We document that firms experience large negati...
# 2-s2.0-85144347623                     Open cloze tests are a standard type of exerci...
# 10.3778/j.issn.1673-9418.2406055       As the potential applications of large languag...
#
#                                       Financial instrument?      Instrument  \
# ID
# 2-s2.0-105007166117                                      ✔️    Stock/Equity
# 2-s2.0-105013137151                                       ❌               ?
# 2-s2.0-105009402610                                      ✔️    Stock/Equity
# 2-s2.0-85190369483                                       ✔️  Cryptocurrency
# 2-s2.0-85216976361                                        ❌               ?
# 2-s2.0-85201236297                                       ✔️    Stock/Equity
# 2-s2.0-105004809261                                      ✔️    Stock/Equity
# 2-s2.0-85212494941                                       ✔️    Stock/Equity
# 2-s2.0-105007848472                                       ❌               ?
# 2-s2.0-85176944442                                       ✔️  Cryptocurrency
# 10.1109/ISCMI63661.2024.10851487                         ✔️    Stock/Equity
# 10.32473/flairs.v35i.130668                               ❌               ?
# 10.18653/v1/2023.findings-emnlp.490                      ✔️          Option
# 10.3390/jrfm18020099                                     ✔️    Stock/Equity
# 10.1109/ACCESS.2024.3404862                              ✔️  Cryptocurrency
# 10.1145/3637528.3671440                                  ✔️          Option
# 10.1038/s41598-024-56740-9                               ✔️    Stock/Equity
# 10.1016/j.ejor.2024.09.011                                ❌               ?
# 10.1016/j.artmed.2025.103203                             ✔️  Cryptocurrency
# WOS:001225271800001                                      ✔️         Futures
# WOS:001421563000001                                      ✔️  Cryptocurrency
# 10.1063/5.0274031                                        ✔️    Stock/Equity
# 10.1007/978-3-031-55536-7                                ✔️    Stock/Equity
# 10.1145/3677052.3698694                                  ✔️    Stock/Equity
# 10.1145/3707649                                          ✔️          Option
# 10.1016/j.frl.2025.106967                                ✔️  Cryptocurrency
# WOS:001540458000194                                      ✔️          Option
# WOS:001545134000011                                      ✔️            Bond
# 10.1145/3677052.3698681                                  ✔️    Stock/Equity
# 10.1007/978-3-031-84371-6_3                              ✔️  Cryptocurrency
# 10.1109/I2CT61223.2024.10543356                          ✔️  Cryptocurrency
# 10.1016/j.jer.2023.09.019                                ✔️         Futures
# 10.1109/ICSCNA58489.2023.10370253                        ✔️    Stock/Equity
# 10.3389/frai.2025.1609097                                 ❌               ?
# 10.1001/jamasurg.2025.2154                               ✔️  Cryptocurrency
# 10.3390/e27060550                                        ✔️    Stock/Equity
# WOS:001343416300025                                      ✔️    Stock/Equity
# WOS:001374817300001                                      ✔️         Futures
# 10.1145/3652037.3652047                                  ✔️    Stock/Equity
# 10.1145/3651655.3651658                                  ✔️         Futures
# 10.16097/j.cnki.1009-6744.2025.04.014                    ✔️         Futures
# 10.1145/3677052.3698627                                  ✔️  Cryptocurrency
# 10.1145/3626772.3657882                                  ✔️          Option
# 10.1109/CogSIMA61085.2024.10553755                       ✔️          Option
# 2-s2.0-105000518469                                       ❌               ?
# 10.3390/nu17071176                                       ✔️    Stock/Equity
# 10.22495/rgcv15i2p13                                     ✔️    Stock/Equity
# 10.1093/rof/rfaf015                                      ✔️    Stock/Equity
# 2-s2.0-85144347623                                       ✔️          Option
# 10.3778/j.issn.1673-9418.2406055                         ✔️    Stock/Equity
#
#                                       AI? LLM?
# ID
# 2-s2.0-105007166117                    ✔️   ✔️
# 2-s2.0-105013137151                     ❌   ✔️
# 2-s2.0-105009402610                    ✔️   ✔️
# 2-s2.0-85190369483                     ✔️   ✔️
# 2-s2.0-85216976361                     ✔️   ✔️
# 2-s2.0-85201236297                     ✔️   ✔️
# 2-s2.0-105004809261                    ✔️   ✔️
# 2-s2.0-85212494941                     ✔️   ✔️
# 2-s2.0-105007848472                     ❌   ✔️
# 2-s2.0-85176944442                     ✔️   ✔️
# 10.1109/ISCMI63661.2024.10851487       ✔️   ✔️
# 10.32473/flairs.v35i.130668            ✔️   ✔️
# 10.18653/v1/2023.findings-emnlp.490    ✔️   ✔️
# 10.3390/jrfm18020099                   ✔️   ✔️
# 10.1109/ACCESS.2024.3404862            ✔️   ✔️
# 10.1145/3637528.3671440                 ❌   ✔️
# 10.1038/s41598-024-56740-9             ✔️   ✔️
# 10.1016/j.ejor.2024.09.011             ✔️   ✔️
# 10.1016/j.artmed.2025.103203            ❌   ✔️
# WOS:001225271800001                    ✔️   ✔️
# WOS:001421563000001                    ✔️   ✔️
# 10.1063/5.0274031                      ✔️   ✔️
# 10.1007/978-3-031-55536-7              ✔️   ✔️
# 10.1145/3677052.3698694                ✔️   ✔️
# 10.1145/3707649                         ❌   ✔️
# 10.1016/j.frl.2025.106967              ✔️   ✔️
# WOS:001540458000194                     ❌   ✔️
# WOS:001545134000011                    ✔️   ✔️
# 10.1145/3677052.3698681                 ❌   ✔️
# 10.1007/978-3-031-84371-6_3            ✔️   ✔️
# 10.1109/I2CT61223.2024.10543356        ✔️   ✔️
# 10.1016/j.jer.2023.09.019              ✔️   ✔️
# 10.1109/ICSCNA58489.2023.10370253       ❌   ✔️
# 10.3389/frai.2025.1609097               ❌   ✔️
# 10.1001/jamasurg.2025.2154             ✔️   ✔️
# 10.3390/e27060550                      ✔️   ✔️
# WOS:001343416300025                     ❌   ✔️
# WOS:001374817300001                    ✔️   ✔️
# 10.1145/3652037.3652047                ✔️   ✔️
# 10.1145/3651655.3651658                ✔️   ✔️
# 10.16097/j.cnki.1009-6744.2025.04.014   ❌   ✔️
# 10.1145/3677052.3698627                ✔️   ✔️
# 10.1145/3626772.3657882                ✔️   ✔️
# 10.1109/CogSIMA61085.2024.10553755     ✔️   ✔️
# 2-s2.0-105000518469                     ❌   ✔️
# 10.3390/nu17071176                     ✔️   ✔️
# 10.22495/rgcv15i2p13                   ✔️   ✔️
# 10.1093/rof/rfaf015                     ❌   ✔️
# 2-s2.0-85144347623                     ✔️   ✔️
# 10.3778/j.issn.1673-9418.2406055       ✔️   ✔️

# %%
# Generate prompts to Chat GPT
import os
from IPython.display import clear_output

batch_size = 50
i = 0

# Filter clean df on whether a gpt assessment has already been done
input_df = clean_df.drop(gpt_response_df.index, errors='ignore')[["Title", "Abstract"]]

for batch in range(0, len(input_df), batch_size):
    batch_df = input_df.iloc[batch:batch+batch_size]
    print("""
For the following CSV list of articles, please return a CSV with the following columns:
- `ID`: The ID of the article, corresponding to the ID in the provided CSV
- `Summary`: A one-to-two sentence summary of the article
- `Financial instrument?`: A column with the value ✔️ if the article contains a model that predicts the price of a financial instrument and ❌ otherwise
- `Instrument`: A column with the type of the financial instrument that is predicted
- `AI?`: A column with the value ✔️ if the model in the article is an AI/ML model (i.e. more advanced than traditional econometric models) and ❌ otherwise
- `Probabilistic?`: A column with the value ✔️ if the model is a **probablistic** AI model (i.e. the prediction includes either variance or a distribution or some other financial risk measure such as VaR) and ❌ otherwise
You can also answer "?" to any question if it cannot be answered based on the title or abstract.
Please ensure that the CSV is valid by applying quotation marks wherever necessary.
""")
    print(batch_df.to_csv(index=True))
    input("Press enter to get next prompt")
    clear_output(wait=True)
# Out:
# For the following CSV list of articles, please return a CSV with the following columns:
# - `ID`: The ID of the article, corresponding to the ID in the provided CSV
# - `Summary`: A one-to-two sentence summary of the article
# - `Financial instrument?`: A column with the value ✔️ if the article contains a model that predicts the price of a financial instrument and ❌ otherwise
# - `Instrument`: A column with the type of the financial instrument that is predicted
# - `AI?`: A column with the value ✔️ if the model in the article is an AI/ML model (i.e. more advanced than traditional econometric models) and ❌ otherwise
# - `Probabilistic?`: A column with the value ✔️ if the model is a **probablistic** AI model (i.e. the prediction includes either variance or a distribution or some other financial risk measure such as VaR) and ❌ otherwise
# You can also answer "?" to any question if it cannot be answered based on the title or abstract.
# Please ensure that the CSV is valid by applying quotation marks wherever necessary.
#
# ID,Title,Abstract
# 10.18653/v1/2021.semeval-1.87,cs60075 team2 at SemEval-2021 Task 1: Lexical Complexity Prediction using Transformer-based Language Models pre-trained on various text corpora,"This paper describes the performance of the team cs60075 team2 at SemEval 2021 Task 1 - Lexical Complexity Prediction. The main contribution of this paper is to fine-tune transformer-based language models pre-trained on several text corpora, some being general (E.g., Wikipedia, BooksCorpus), some being the corpora from which the CompLex Dataset was extracted, and others being from other specific domains such as Finance, Law, etc. We perform ablation studies on selecting the transformer models and how their individual complexity scores are aggregated to get the resulting complexity scores. Our method1 achieves a best Pearson Correlation of 0.784 in sub-task 1 (single word) and 0.836 in sub-task 2 (multiple word expressions). © 2025 Elsevier B.V., All rights reserved."

# %% [markdown]
# ### Load Assessments

# %%
# Load all assessments
gpt_response_df = pd.read_csv("gpt.csv", index_col="ID")
gpt_response_df
# Out:
#                                                                                  Summary  \
# ID
# 2-s2.0-105007166117                    The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                    The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                    The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                     The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                     The proceedings contain 57 papers. The topics ...
# 2-s2.0-85201236297                     The proceedings contain 98 papers. The topics ...
# 2-s2.0-105004809261                    The proceedings contain 11 papers. The topics ...
# 2-s2.0-85212494941                     The proceedings contain 52 papers. The special...
# 2-s2.0-105007848472                    The proceedings contain 40 papers. The special...
# 2-s2.0-85176944442                     The proceedings contain 28 papers. The special...
# 10.1109/ISCMI63661.2024.10851487       Time series analysis of daily stock prices is ...
# 10.32473/flairs.v35i.130668            Purchasing a home is one of the largest invest...
# 10.18653/v1/2023.findings-emnlp.490    Large language models (LLMs) have demonstrated...
# 10.3390/jrfm18020099                   OpenAI’s new flagship model, ChatGPT-4o, relea...
# 10.1109/ACCESS.2024.3404862            In the face of rapidly increasing crime rates,...
# 10.1145/3637528.3671440                This tutorial offers a comprehensive guide on ...
# 10.1038/s41598-024-56740-9             English speakers use probabilistic phrases suc...
# 10.1016/j.ejor.2024.09.011             Investors are continuously seeking profitable ...
# 10.1016/j.artmed.2025.103203           As a systemic problem, public health cannot be...
# WOS:001225271800001                    In contemporary societies, the processes of tr...
# WOS:001421563000001                    Policy uncertainty is a potential source for r...
# 10.1063/5.0274031                      Large language models (LLMs) are reshaping the...
# 10.1007/978-3-031-55536-7              This book is a comprehensive guide to the use ...
# 10.1145/3677052.3698694                Investment Analysis is a cornerstone of the Fi...
# 10.1145/3707649                        Large language models (LLMs) match and sometim...
# 10.1016/j.frl.2025.106967              Financial risk prediction is crucial for inves...
# WOS:001540458000194                    Considering privacy concerns and real-time dem...
# WOS:001545134000011                    Large Language Models (LLM) empower many moder...
# 10.1145/3677052.3698681                Recent strategies for portfolio management oft...
# 10.1007/978-3-031-84371-6_3            In this study, we investigate the role of Gene...
# 10.1109/I2CT61223.2024.10543356        This paper presents the development of a groun...
# 10.1016/j.jer.2023.09.019              Road accidents have been progressively causing...
# 10.1109/ICSCNA58489.2023.10370253      Company' s brand perception majorly depends on...
# 10.3389/frai.2025.1609097              Large Language Models (LLMs) have significantl...
# 10.1001/jamasurg.2025.2154             Importance: Accurate prediction of surgical ca...
# 10.3390/e27060550                      This study examines the effectiveness of combi...
# WOS:001343416300025                    The abundance of tabular microdata constitutes...
# WOS:001374817300001                    Background: ChatGPT (Open AI) is a state-of-th...
# 10.1145/3652037.3652047                In accordance with the findings presented in [...
# 10.1145/3651655.3651658                As decentralized finance (DeFi) built on block...
# 10.16097/j.cnki.1009-6744.2025.04.014  Aiming at the problems that the high- level de...
# 10.1145/3677052.3698627                Predicting bankruptcy is crucial for managing ...
# 10.1145/3626772.3657882                GPT-4 demonstrates high accuracy in medical QA...
# 10.1109/CogSIMA61085.2024.10553755     Large language models (LLMs), like OpenAI’s Ch...
# 2-s2.0-105000518469                    We present a novel statistical framework for a...
# 10.3390/nu17071176                     Background/Objectives: Weight management is di...
# 10.22495/rgcv15i2p13                   The use of artificial intelligence (AI) in fin...
# 10.1093/rof/rfaf015                    We document that firms experience large negati...
# 2-s2.0-85144347623                     Open cloze tests are a standard type of exerci...
# 10.3778/j.issn.1673-9418.2406055       As the potential applications of large languag...
#
#                                       Financial instrument?      Instrument  \
# ID
# 2-s2.0-105007166117                                      ✔️    Stock/Equity
# 2-s2.0-105013137151                                       ❌               ?
# 2-s2.0-105009402610                                      ✔️    Stock/Equity
# 2-s2.0-85190369483                                       ✔️  Cryptocurrency
# 2-s2.0-85216976361                                        ❌               ?
# 2-s2.0-85201236297                                       ✔️    Stock/Equity
# 2-s2.0-105004809261                                      ✔️    Stock/Equity
# 2-s2.0-85212494941                                       ✔️    Stock/Equity
# 2-s2.0-105007848472                                       ❌               ?
# 2-s2.0-85176944442                                       ✔️  Cryptocurrency
# 10.1109/ISCMI63661.2024.10851487                         ✔️    Stock/Equity
# 10.32473/flairs.v35i.130668                               ❌               ?
# 10.18653/v1/2023.findings-emnlp.490                      ✔️          Option
# 10.3390/jrfm18020099                                     ✔️    Stock/Equity
# 10.1109/ACCESS.2024.3404862                              ✔️  Cryptocurrency
# 10.1145/3637528.3671440                                  ✔️          Option
# 10.1038/s41598-024-56740-9                               ✔️    Stock/Equity
# 10.1016/j.ejor.2024.09.011                                ❌               ?
# 10.1016/j.artmed.2025.103203                             ✔️  Cryptocurrency
# WOS:001225271800001                                      ✔️         Futures
# WOS:001421563000001                                      ✔️  Cryptocurrency
# 10.1063/5.0274031                                        ✔️    Stock/Equity
# 10.1007/978-3-031-55536-7                                ✔️    Stock/Equity
# 10.1145/3677052.3698694                                  ✔️    Stock/Equity
# 10.1145/3707649                                          ✔️          Option
# 10.1016/j.frl.2025.106967                                ✔️  Cryptocurrency
# WOS:001540458000194                                      ✔️          Option
# WOS:001545134000011                                      ✔️            Bond
# 10.1145/3677052.3698681                                  ✔️    Stock/Equity
# 10.1007/978-3-031-84371-6_3                              ✔️  Cryptocurrency
# 10.1109/I2CT61223.2024.10543356                          ✔️  Cryptocurrency
# 10.1016/j.jer.2023.09.019                                ✔️         Futures
# 10.1109/ICSCNA58489.2023.10370253                        ✔️    Stock/Equity
# 10.3389/frai.2025.1609097                                 ❌               ?
# 10.1001/jamasurg.2025.2154                               ✔️  Cryptocurrency
# 10.3390/e27060550                                        ✔️    Stock/Equity
# WOS:001343416300025                                      ✔️    Stock/Equity
# WOS:001374817300001                                      ✔️         Futures
# 10.1145/3652037.3652047                                  ✔️    Stock/Equity
# 10.1145/3651655.3651658                                  ✔️         Futures
# 10.16097/j.cnki.1009-6744.2025.04.014                    ✔️         Futures
# 10.1145/3677052.3698627                                  ✔️  Cryptocurrency
# 10.1145/3626772.3657882                                  ✔️          Option
# 10.1109/CogSIMA61085.2024.10553755                       ✔️          Option
# 2-s2.0-105000518469                                       ❌               ?
# 10.3390/nu17071176                                       ✔️    Stock/Equity
# 10.22495/rgcv15i2p13                                     ✔️    Stock/Equity
# 10.1093/rof/rfaf015                                      ✔️    Stock/Equity
# 2-s2.0-85144347623                                       ✔️          Option
# 10.3778/j.issn.1673-9418.2406055                         ✔️    Stock/Equity
#
#                                       AI? LLM?
# ID
# 2-s2.0-105007166117                    ✔️   ✔️
# 2-s2.0-105013137151                     ❌   ✔️
# 2-s2.0-105009402610                    ✔️   ✔️
# 2-s2.0-85190369483                     ✔️   ✔️
# 2-s2.0-85216976361                     ✔️   ✔️
# 2-s2.0-85201236297                     ✔️   ✔️
# 2-s2.0-105004809261                    ✔️   ✔️
# 2-s2.0-85212494941                     ✔️   ✔️
# 2-s2.0-105007848472                     ❌   ✔️
# 2-s2.0-85176944442                     ✔️   ✔️
# 10.1109/ISCMI63661.2024.10851487       ✔️   ✔️
# 10.32473/flairs.v35i.130668            ✔️   ✔️
# 10.18653/v1/2023.findings-emnlp.490    ✔️   ✔️
# 10.3390/jrfm18020099                   ✔️   ✔️
# 10.1109/ACCESS.2024.3404862            ✔️   ✔️
# 10.1145/3637528.3671440                 ❌   ✔️
# 10.1038/s41598-024-56740-9             ✔️   ✔️
# 10.1016/j.ejor.2024.09.011             ✔️   ✔️
# 10.1016/j.artmed.2025.103203            ❌   ✔️
# WOS:001225271800001                    ✔️   ✔️
# WOS:001421563000001                    ✔️   ✔️
# 10.1063/5.0274031                      ✔️   ✔️
# 10.1007/978-3-031-55536-7              ✔️   ✔️
# 10.1145/3677052.3698694                ✔️   ✔️
# 10.1145/3707649                         ❌   ✔️
# 10.1016/j.frl.2025.106967              ✔️   ✔️
# WOS:001540458000194                     ❌   ✔️
# WOS:001545134000011                    ✔️   ✔️
# 10.1145/3677052.3698681                 ❌   ✔️
# 10.1007/978-3-031-84371-6_3            ✔️   ✔️
# 10.1109/I2CT61223.2024.10543356        ✔️   ✔️
# 10.1016/j.jer.2023.09.019              ✔️   ✔️
# 10.1109/ICSCNA58489.2023.10370253       ❌   ✔️
# 10.3389/frai.2025.1609097               ❌   ✔️
# 10.1001/jamasurg.2025.2154             ✔️   ✔️
# 10.3390/e27060550                      ✔️   ✔️
# WOS:001343416300025                     ❌   ✔️
# WOS:001374817300001                    ✔️   ✔️
# 10.1145/3652037.3652047                ✔️   ✔️
# 10.1145/3651655.3651658                ✔️   ✔️
# 10.16097/j.cnki.1009-6744.2025.04.014   ❌   ✔️
# 10.1145/3677052.3698627                ✔️   ✔️
# 10.1145/3626772.3657882                ✔️   ✔️
# 10.1109/CogSIMA61085.2024.10553755     ✔️   ✔️
# 2-s2.0-105000518469                     ❌   ✔️
# 10.3390/nu17071176                     ✔️   ✔️
# 10.22495/rgcv15i2p13                   ✔️   ✔️
# 10.1093/rof/rfaf015                     ❌   ✔️
# 2-s2.0-85144347623                     ✔️   ✔️
# 10.3778/j.issn.1673-9418.2406055       ✔️   ✔️

# %%
# Remove duplicate indices in gpt_response_df
gpt_response_df = gpt_response_df[~gpt_response_df.index.duplicated(keep='last')]
gpt_response_df
# Out:
#                                                                                  Summary  \
# ID
# 2-s2.0-105007166117                    The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                    The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                    The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                     The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                     The proceedings contain 57 papers. The topics ...
# 2-s2.0-85201236297                     The proceedings contain 98 papers. The topics ...
# 2-s2.0-105004809261                    The proceedings contain 11 papers. The topics ...
# 2-s2.0-85212494941                     The proceedings contain 52 papers. The special...
# 2-s2.0-105007848472                    The proceedings contain 40 papers. The special...
# 2-s2.0-85176944442                     The proceedings contain 28 papers. The special...
# 10.1109/ISCMI63661.2024.10851487       Time series analysis of daily stock prices is ...
# 10.32473/flairs.v35i.130668            Purchasing a home is one of the largest invest...
# 10.18653/v1/2023.findings-emnlp.490    Large language models (LLMs) have demonstrated...
# 10.3390/jrfm18020099                   OpenAI’s new flagship model, ChatGPT-4o, relea...
# 10.1109/ACCESS.2024.3404862            In the face of rapidly increasing crime rates,...
# 10.1145/3637528.3671440                This tutorial offers a comprehensive guide on ...
# 10.1038/s41598-024-56740-9             English speakers use probabilistic phrases suc...
# 10.1016/j.ejor.2024.09.011             Investors are continuously seeking profitable ...
# 10.1016/j.artmed.2025.103203           As a systemic problem, public health cannot be...
# WOS:001225271800001                    In contemporary societies, the processes of tr...
# WOS:001421563000001                    Policy uncertainty is a potential source for r...
# 10.1063/5.0274031                      Large language models (LLMs) are reshaping the...
# 10.1007/978-3-031-55536-7              This book is a comprehensive guide to the use ...
# 10.1145/3677052.3698694                Investment Analysis is a cornerstone of the Fi...
# 10.1145/3707649                        Large language models (LLMs) match and sometim...
# 10.1016/j.frl.2025.106967              Financial risk prediction is crucial for inves...
# WOS:001540458000194                    Considering privacy concerns and real-time dem...
# WOS:001545134000011                    Large Language Models (LLM) empower many moder...
# 10.1145/3677052.3698681                Recent strategies for portfolio management oft...
# 10.1007/978-3-031-84371-6_3            In this study, we investigate the role of Gene...
# 10.1109/I2CT61223.2024.10543356        This paper presents the development of a groun...
# 10.1016/j.jer.2023.09.019              Road accidents have been progressively causing...
# 10.1109/ICSCNA58489.2023.10370253      Company' s brand perception majorly depends on...
# 10.3389/frai.2025.1609097              Large Language Models (LLMs) have significantl...
# 10.1001/jamasurg.2025.2154             Importance: Accurate prediction of surgical ca...
# 10.3390/e27060550                      This study examines the effectiveness of combi...
# WOS:001343416300025                    The abundance of tabular microdata constitutes...
# WOS:001374817300001                    Background: ChatGPT (Open AI) is a state-of-th...
# 10.1145/3652037.3652047                In accordance with the findings presented in [...
# 10.1145/3651655.3651658                As decentralized finance (DeFi) built on block...
# 10.16097/j.cnki.1009-6744.2025.04.014  Aiming at the problems that the high- level de...
# 10.1145/3677052.3698627                Predicting bankruptcy is crucial for managing ...
# 10.1145/3626772.3657882                GPT-4 demonstrates high accuracy in medical QA...
# 10.1109/CogSIMA61085.2024.10553755     Large language models (LLMs), like OpenAI’s Ch...
# 2-s2.0-105000518469                    We present a novel statistical framework for a...
# 10.3390/nu17071176                     Background/Objectives: Weight management is di...
# 10.22495/rgcv15i2p13                   The use of artificial intelligence (AI) in fin...
# 10.1093/rof/rfaf015                    We document that firms experience large negati...
# 2-s2.0-85144347623                     Open cloze tests are a standard type of exerci...
# 10.3778/j.issn.1673-9418.2406055       As the potential applications of large languag...
#
#                                       Financial instrument?      Instrument  \
# ID
# 2-s2.0-105007166117                                      ✔️    Stock/Equity
# 2-s2.0-105013137151                                       ❌               ?
# 2-s2.0-105009402610                                      ✔️    Stock/Equity
# 2-s2.0-85190369483                                       ✔️  Cryptocurrency
# 2-s2.0-85216976361                                        ❌               ?
# 2-s2.0-85201236297                                       ✔️    Stock/Equity
# 2-s2.0-105004809261                                      ✔️    Stock/Equity
# 2-s2.0-85212494941                                       ✔️    Stock/Equity
# 2-s2.0-105007848472                                       ❌               ?
# 2-s2.0-85176944442                                       ✔️  Cryptocurrency
# 10.1109/ISCMI63661.2024.10851487                         ✔️    Stock/Equity
# 10.32473/flairs.v35i.130668                               ❌               ?
# 10.18653/v1/2023.findings-emnlp.490                      ✔️          Option
# 10.3390/jrfm18020099                                     ✔️    Stock/Equity
# 10.1109/ACCESS.2024.3404862                              ✔️  Cryptocurrency
# 10.1145/3637528.3671440                                  ✔️          Option
# 10.1038/s41598-024-56740-9                               ✔️    Stock/Equity
# 10.1016/j.ejor.2024.09.011                                ❌               ?
# 10.1016/j.artmed.2025.103203                             ✔️  Cryptocurrency
# WOS:001225271800001                                      ✔️         Futures
# WOS:001421563000001                                      ✔️  Cryptocurrency
# 10.1063/5.0274031                                        ✔️    Stock/Equity
# 10.1007/978-3-031-55536-7                                ✔️    Stock/Equity
# 10.1145/3677052.3698694                                  ✔️    Stock/Equity
# 10.1145/3707649                                          ✔️          Option
# 10.1016/j.frl.2025.106967                                ✔️  Cryptocurrency
# WOS:001540458000194                                      ✔️          Option
# WOS:001545134000011                                      ✔️            Bond
# 10.1145/3677052.3698681                                  ✔️    Stock/Equity
# 10.1007/978-3-031-84371-6_3                              ✔️  Cryptocurrency
# 10.1109/I2CT61223.2024.10543356                          ✔️  Cryptocurrency
# 10.1016/j.jer.2023.09.019                                ✔️         Futures
# 10.1109/ICSCNA58489.2023.10370253                        ✔️    Stock/Equity
# 10.3389/frai.2025.1609097                                 ❌               ?
# 10.1001/jamasurg.2025.2154                               ✔️  Cryptocurrency
# 10.3390/e27060550                                        ✔️    Stock/Equity
# WOS:001343416300025                                      ✔️    Stock/Equity
# WOS:001374817300001                                      ✔️         Futures
# 10.1145/3652037.3652047                                  ✔️    Stock/Equity
# 10.1145/3651655.3651658                                  ✔️         Futures
# 10.16097/j.cnki.1009-6744.2025.04.014                    ✔️         Futures
# 10.1145/3677052.3698627                                  ✔️  Cryptocurrency
# 10.1145/3626772.3657882                                  ✔️          Option
# 10.1109/CogSIMA61085.2024.10553755                       ✔️          Option
# 2-s2.0-105000518469                                       ❌               ?
# 10.3390/nu17071176                                       ✔️    Stock/Equity
# 10.22495/rgcv15i2p13                                     ✔️    Stock/Equity
# 10.1093/rof/rfaf015                                      ✔️    Stock/Equity
# 2-s2.0-85144347623                                       ✔️          Option
# 10.3778/j.issn.1673-9418.2406055                         ✔️    Stock/Equity
#
#                                       AI? LLM?
# ID
# 2-s2.0-105007166117                    ✔️   ✔️
# 2-s2.0-105013137151                     ❌   ✔️
# 2-s2.0-105009402610                    ✔️   ✔️
# 2-s2.0-85190369483                     ✔️   ✔️
# 2-s2.0-85216976361                     ✔️   ✔️
# 2-s2.0-85201236297                     ✔️   ✔️
# 2-s2.0-105004809261                    ✔️   ✔️
# 2-s2.0-85212494941                     ✔️   ✔️
# 2-s2.0-105007848472                     ❌   ✔️
# 2-s2.0-85176944442                     ✔️   ✔️
# 10.1109/ISCMI63661.2024.10851487       ✔️   ✔️
# 10.32473/flairs.v35i.130668            ✔️   ✔️
# 10.18653/v1/2023.findings-emnlp.490    ✔️   ✔️
# 10.3390/jrfm18020099                   ✔️   ✔️
# 10.1109/ACCESS.2024.3404862            ✔️   ✔️
# 10.1145/3637528.3671440                 ❌   ✔️
# 10.1038/s41598-024-56740-9             ✔️   ✔️
# 10.1016/j.ejor.2024.09.011             ✔️   ✔️
# 10.1016/j.artmed.2025.103203            ❌   ✔️
# WOS:001225271800001                    ✔️   ✔️
# WOS:001421563000001                    ✔️   ✔️
# 10.1063/5.0274031                      ✔️   ✔️
# 10.1007/978-3-031-55536-7              ✔️   ✔️
# 10.1145/3677052.3698694                ✔️   ✔️
# 10.1145/3707649                         ❌   ✔️
# 10.1016/j.frl.2025.106967              ✔️   ✔️
# WOS:001540458000194                     ❌   ✔️
# WOS:001545134000011                    ✔️   ✔️
# 10.1145/3677052.3698681                 ❌   ✔️
# 10.1007/978-3-031-84371-6_3            ✔️   ✔️
# 10.1109/I2CT61223.2024.10543356        ✔️   ✔️
# 10.1016/j.jer.2023.09.019              ✔️   ✔️
# 10.1109/ICSCNA58489.2023.10370253       ❌   ✔️
# 10.3389/frai.2025.1609097               ❌   ✔️
# 10.1001/jamasurg.2025.2154             ✔️   ✔️
# 10.3390/e27060550                      ✔️   ✔️
# WOS:001343416300025                     ❌   ✔️
# WOS:001374817300001                    ✔️   ✔️
# 10.1145/3652037.3652047                ✔️   ✔️
# 10.1145/3651655.3651658                ✔️   ✔️
# 10.16097/j.cnki.1009-6744.2025.04.014   ❌   ✔️
# 10.1145/3677052.3698627                ✔️   ✔️
# 10.1145/3626772.3657882                ✔️   ✔️
# 10.1109/CogSIMA61085.2024.10553755     ✔️   ✔️
# 2-s2.0-105000518469                     ❌   ✔️
# 10.3390/nu17071176                     ✔️   ✔️
# 10.22495/rgcv15i2p13                   ✔️   ✔️
# 10.1093/rof/rfaf015                     ❌   ✔️
# 2-s2.0-85144347623                     ✔️   ✔️
# 10.3778/j.issn.1673-9418.2406055       ✔️   ✔️

# %%
processed_df = clean_df.join(gpt_response_df)
processed_df
# Out:
#                                                                                  Title  \
# ID
# 2-s2.0-105007166117                  12th International Conference on HCI in Busine...
# 2-s2.0-105013137151                  14th Symposium on Languages, Applications and ...
# 2-s2.0-105009402610                  18th International Conference on Information T...
# 2-s2.0-85190369483                   2023 IEEE International Conference on Enabling...
# 2-s2.0-85216976361                   2024 6th International Conference on Machine L...
# ...                                                                                ...
# 10.3905/jpm.2025.1.710               Using Large Language Models to Estimate Novel ...
# 10.1177/10534512241235896            Utilizing Text-Generative AI for Creating Oral...
# 10.1109/ACCESS.2025.3532995          Zero-Shot Classification of Art with Large Lan...
# 10.1109/ITC-CSCC66376.2025.11137629  Zero-Shot Time Series Forecasting of the Onlin...
# 10.18653/v1/2021.semeval-1.87        cs60075 team2 at SemEval-2021 Task 1: Lexical ...
#
#                                                                      DOI  \
# ID
# 2-s2.0-105007166117                                                 None
# 2-s2.0-105013137151                                                 None
# 2-s2.0-105009402610                                                 None
# 2-s2.0-85190369483                                                  None
# 2-s2.0-85216976361                                                  None
# ...                                                                  ...
# 10.3905/jpm.2025.1.710                            10.3905/jpm.2025.1.710
# 10.1177/10534512241235896                      10.1177/10534512241235896
# 10.1109/ACCESS.2025.3532995                  10.1109/access.2025.3532995
# 10.1109/ITC-CSCC66376.2025.11137629  10.1109/itc-cscc66376.2025.11137629
# 10.18653/v1/2021.semeval-1.87              10.18653/v1/2021.semeval-1.87
#
#                                                                               Abstract  \
# ID
# 2-s2.0-105007166117                  The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                  The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                  The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                   The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                   The proceedings contain 57 papers. The topics ...
# ...                                                                                ...
# 10.3905/jpm.2025.1.710               This article presents an integrated framework ...
# 10.1177/10534512241235896            Oral reading fluency probes are essential for ...
# 10.1109/ACCESS.2025.3532995          Art has become an important new investment veh...
# 10.1109/ITC-CSCC66376.2025.11137629  This study introduces a zero-shot forecasting ...
# 10.18653/v1/2021.semeval-1.87        This paper describes the performance of the te...
#
#                                                                               Keywords  \
# ID
# 2-s2.0-105007166117                                                               None
# 2-s2.0-105013137151                                                               None
# 2-s2.0-105009402610                                                               None
# 2-s2.0-85190369483                                                                None
# 2-s2.0-85216976361                                                                None
# ...                                                                                ...
# 10.3905/jpm.2025.1.710                                                            None
# 10.1177/10534512241235896            Academic Intervention; Artificial Intelligence...
# 10.1109/ACCESS.2025.3532995          Art; Auction Price; Chatgpt; Classification; D...
# 10.1109/ITC-CSCC66376.2025.11137629  Online Gig Economy; Online Labor Index; Pre-tr...
# 10.18653/v1/2021.semeval-1.87        Correlation Methods; Semantics; Complex Datase...
#
#                                      Origin  \
# ID
# 2-s2.0-105007166117                  Scopus
# 2-s2.0-105013137151                  Scopus
# 2-s2.0-105009402610                  Scopus
# 2-s2.0-85190369483                   Scopus
# 2-s2.0-85216976361                   Scopus
# ...                                     ...
# 10.3905/jpm.2025.1.710               Scopus
# 10.1177/10534512241235896            Scopus
# 10.1109/ACCESS.2025.3532995          Scopus
# 10.1109/ITC-CSCC66376.2025.11137629  Scopus
# 10.18653/v1/2021.semeval-1.87        Scopus
#
#                                                                                Summary  \
# ID
# 2-s2.0-105007166117                  The proceedings contain 41 papers. The special...
# 2-s2.0-105013137151                  The proceedings contain 13 papers. The topics ...
# 2-s2.0-105009402610                  The proceedings contain 59 papers. The special...
# 2-s2.0-85190369483                   The proceedings contain 36 papers. The topics ...
# 2-s2.0-85216976361                   The proceedings contain 57 papers. The topics ...
# ...                                                                                ...
# 10.3905/jpm.2025.1.710                                                             NaN
# 10.1177/10534512241235896                                                          NaN
# 10.1109/ACCESS.2025.3532995                                                        NaN
# 10.1109/ITC-CSCC66376.2025.11137629                                                NaN
# 10.18653/v1/2021.semeval-1.87                                                      NaN
#
#                                     Financial instrument?      Instrument  \
# ID
# 2-s2.0-105007166117                                    ✔️    Stock/Equity
# 2-s2.0-105013137151                                     ❌               ?
# 2-s2.0-105009402610                                    ✔️    Stock/Equity
# 2-s2.0-85190369483                                     ✔️  Cryptocurrency
# 2-s2.0-85216976361                                      ❌               ?
# ...                                                   ...             ...
# 10.3905/jpm.2025.1.710                                NaN             NaN
# 10.1177/10534512241235896                             NaN             NaN
# 10.1109/ACCESS.2025.3532995                           NaN             NaN
# 10.1109/ITC-CSCC66376.2025.11137629                   NaN             NaN
# 10.18653/v1/2021.semeval-1.87                         NaN             NaN
#
#                                      AI? LLM?
# ID
# 2-s2.0-105007166117                   ✔️   ✔️
# 2-s2.0-105013137151                    ❌   ✔️
# 2-s2.0-105009402610                   ✔️   ✔️
# 2-s2.0-85190369483                    ✔️   ✔️
# 2-s2.0-85216976361                    ✔️   ✔️
# ...                                  ...  ...
# 10.3905/jpm.2025.1.710               NaN  NaN
# 10.1177/10534512241235896            NaN  NaN
# 10.1109/ACCESS.2025.3532995          NaN  NaN
# 10.1109/ITC-CSCC66376.2025.11137629  NaN  NaN
# 10.18653/v1/2021.semeval-1.87        NaN  NaN
#
# [251 rows x 10 columns]

# %% [markdown]
# # 4. Make decisions on whether to include articles

# %%
# Load previous decisions
decisions_file_path = "decisions.csv"
decisions_df = pd.read_csv(decisions_file_path, index_col=0)
decisions_df.sort_values("Date", ascending=True)
# Out:
# Empty DataFrame
# Columns: [Decision, Date, Reviewer]
# Index: []

# %%
# Keep own version to mitigate overwriting each other
my_decisions_df = decisions_df.copy()

# %%
from datetime import datetime
from IPython.display import display, HTML, clear_output

reviewer = input("What is your name?")

# Shuffle the indices of the DataFrame to limit chance of two people reviewing the same article at the same time
np.random.seed(hash(reviewer) % 2**32)
shuffled_indices = np.random.permutation(processed_df.index)

def get_progress():
    decided = set(decisions_df.index).intersection(processed_df.index)
    return len(decided) / len(processed_df)

# Loop through the randomized indices
for index in shuffled_indices:
    row = processed_df.loc[index]
    if index in my_decisions_df.index:
        continue
    if index in skipped:
        continue
    if len(row.shape) > 1:
        row = row.iloc[0]
    if pd.isna(row["Summary"]):
        continue
    clear_output(wait=True)
    print(f"Screening progress: {get_progress() * 100:.2f}%")
    display(HTML(f'<h1>{row["Title"]}</h1>'))
    print("ID:", index)
    display(HTML(f'<a href="https://doi.org/{row["DOI"]}" target="_blank">Link</a>'))
    display(HTML(f'<h2>GPT assessment</h2>'))
    display(HTML(f'<p style="font-size:20px;">Financial instrument?: {row["Financial instrument?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">AI?: {row["AI?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">LLM?: {row["LLM?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">Instrument: {row["Instrument"]}</p>'))
    display(HTML(f'<h2>Summary</h2>'))
    display(HTML(f'<p style="font-size:18px;line-height:30px">{row["Summary"]}</p>'))
    display(HTML(f'<h2>Keywords</h2>'))
    display(HTML(f'<p style="font-size:18px;line-height:30px">{row["Keywords"]}</p>'))
    display(HTML(f'<h2>Abstract</h2>'))
    display(HTML(f'<p style="font-size:16px;line-height:24px">{row["Abstract"]}</p>'))
    decision = None
    while decision not in ["y", "n", "survey", "tja", "skip"]:
        decision = input("\nInclude this article? (y/n/survey/tja/skip):\n").lower()
    if decision == "skip":
        skipped.add(index)
        continue
    # Add decision
    my_decisions_df.loc[index] = [decision, datetime.now().isoformat(), reviewer]
    # Ensure latest version of file
    # mount()
    decisions_df = pd.read_csv(decisions_file_path, index_col=0)
    # Add any entries in my_decisions_df that are not in decisions_df
    decisions_df = pd.concat([decisions_df, my_decisions_df])
    # Remove rows that are strictly equal
    decisions_df = decisions_df.drop_duplicates(keep="last")
    # Save
    decisions_df.to_csv(decisions_file_path)
# Out:
# Screening progress: 0.40%
# <h1>A First Look at Financial Data Analysis Using ChatGPT-4o</h1>
# ID: 10.3390/jrfm18020099
# <a href="https://doi.org/10.3390/jrfm18020099" target="_blank">Link</a>
# <h2>GPT assessment</h2>
# <p style="font-size:20px;">Financial instrument?: ✔️</p>
# <p style="font-size:20px;">AI?: ✔️</p>
# <p style="font-size:20px;">LLM?: ✔️</p>
# <p style="font-size:20px;">Instrument: Stock/Equity</p>
# <h2>Summary</h2>
# <p style="font-size:18px;line-height:30px">OpenAI’s new flagship model, ChatGPT-4o, released on 13 May 2024, offers enhanced natural language understanding and more coherent responses. This paper investigates ChatGPT-4o’s capabilities in financial data analysis, including zero-shot prompting, time series analysis, risk and return analysis, and ARMA-GARCH estimation.</p>
# <h2>Keywords</h2>
# <p style="font-size:18px;line-height:30px">Academia; Artificial Intelligence (ai); Chatgpt; Data Analysis; Finance Research; Financial Analysis; Generative Ai (genai); Large Language Models; Stock Return</p>
# <h2>Abstract</h2>
# <p style="font-size:16px;line-height:24px">OpenAI’s new flagship model, ChatGPT-4o, released on 13 May 2024, offers enhanced natural language understanding and more coherent responses. This paper investigates ChatGPT-4o’s capabilities in financial data analysis, including zero-shot prompting, time series analysis, risk and return analysis, and ARMA-GARCH estimation. ChatGPT-4o’s performance is generally comparable to traditional statistical software like Stata, though some errors and discrepancies arise due to differences in implementation. Despite these issues, our findings indicate that ChatGPT-4o has significant potential for real-world financial analysis. Integrating ChatGPT-4o into financial research and practice may lead to more efficient data processing, improved analytical capabilities, and better-informed investment decisions. © 2025 Elsevier B.V., All rights reserved.</p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 43
#      41 decision = None
#      42 while decision not in ["y", "n", "survey", "tja", "skip"]:
# ---> 43     decision = input("\nInclude this article? (y/n/survey/tja/skip):\n").lower()
#      44 if decision == "skip":
#      45     skipped.add(index)
#
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
