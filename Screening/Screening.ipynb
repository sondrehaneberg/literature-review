# %%
import pandas as pd
import numpy as np

# %%
# Set used to keep track of any skipped decisions (placed here to not be reset without purpose)
skipped = set()

# %% [markdown]
# # 1. Import data

# %% [markdown]
# ## 1.1 Scopus

# %%
scopus_df = pd.read_csv("Scopus.csv")
print(scopus_df.columns)
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Funding Texts', 'References', 'Editors', 'Publisher', 'Sponsors',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
clean_scopus_df = scopus_df[["DOI", "Title", "Abstract", "Author Keywords"]].copy()
clean_scopus_df.columns = ["DOI", "Title", "Abstract", "Keywords"]
clean_scopus_df["ID"] = np.where(pd.isna(clean_scopus_df["DOI"]), scopus_df["EID"], clean_scopus_df["DOI"])
clean_scopus_df = clean_scopus_df.set_index("ID")
clean_scopus_df["Origin"] = "Scopus"
clean_scopus_df.index.name = "ID"
clean_scopus_df
# Out:
#                                                        DOI  \
# ID
# 10.1007/978-981-96-6291-3_3    10.1007/978-981-96-6291-3_3
# 10.1016/j.eswa.2025.128676      10.1016/j.eswa.2025.128676
# 10.1186/s40854-025-00789-6      10.1186/s40854-025-00789-6
# 10.1016/j.frl.2025.108489        10.1016/j.frl.2025.108489
# 10.1007/s12525-025-00815-6      10.1007/s12525-025-00815-6
# ...                                                    ...
# 10.18653/v1/d15-1184                  10.18653/v1/d15-1184
# 10.1214/14-AOS1250                      10.1214/14-AOS1250
# 10.1016/j.egypro.2014.02.176  10.1016/j.egypro.2014.02.176
# 2-s2.0-84871531453                                     NaN
# 10.1108/02686900610705037        10.1108/02686900610705037
#
#                                                                                                                                                 Title  \
# ID
# 10.1007/978-981-96-6291-3_3   Stock Price Prediction Using Univariate and Multivariate Historical Data with Post-Interpretation via Large Language...
# 10.1016/j.eswa.2025.128676                                                                          In the beginning was the Word: LLM-VaR and LLM-ES
# 10.1186/s40854-025-00789-6                The power of ChatGPT in processing text: Evidence from analysis and prediction in the exchange rate markets
# 10.1016/j.frl.2025.108489                                                                 Readability of financial reports and stock price crash risk
# 10.1007/s12525-025-00815-6                         Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
# ...                                                                                                                                               ...
# 10.18653/v1/d15-1184                                                                     Reading documents for Bayesian Online Change Point Detection
# 10.1214/14-AOS1250                                                                                       Estimating time-changes in noisy Lévy models
# 10.1016/j.egypro.2014.02.176                                    Solar energy in urban environment: How urban densification affects existing buildings
# 2-s2.0-84871531453                                                 A kernel-based technique for direction-of-change financial time series forecasting
# 10.1108/02686900610705037                                      The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
#
#                                                                                                                                              Abstract  \
# ID
# 10.1007/978-981-96-6291-3_3   In this study, we propose a hybrid approach that utilizes both univariate and multivariate historical data from key ...
# 10.1016/j.eswa.2025.128676    This study introduces LLM-VaR and LLM-ES, novel risk estimation metrics that utilize general-purpose large language ...
# 10.1186/s40854-025-00789-6    This study investigates the application of large language models in analyzing sentiment features within the exchange...
# 10.1016/j.frl.2025.108489     The rapid evolution of machine learning makes text analysis more feasible. Utilizing a large language model, BERT, t...
# 10.1007/s12525-025-00815-6    The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
# ...                                                                                                                                               ...
# 10.18653/v1/d15-1184          Modeling non-stationary time-series data for making predictions is a challenging but important task. One of the key ...
# 10.1214/14-AOS1250            In quantitative finance, we often model asset prices as a noisy Itô semimartingale. As this model is not identifiabl...
# 10.1016/j.egypro.2014.02.176  The paper is focused on a new solar urban planning approach for building densification and preservation in existing ...
# 2-s2.0-84871531453            This paper presents a generative approach to direction-of-change time series forecasting. Kernel methods are used to...
# 10.1108/02686900610705037     Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
#
#                                                                                                                                              Keywords  \
# ID
# 10.1007/978-981-96-6291-3_3      Large Language Models (LLM); Multivariate Analysis; Stock Price Prediction; Time Series Forecasting; Univariate Data
# 10.1016/j.eswa.2025.128676                                             Expected shortfall; GPT; Large language models; LLM-ES; LLM-VaR; Value at risk
# 10.1186/s40854-025-00789-6                                                       ChatGPT; Exchange rate; Interval; Sentiment analysis; Topic analysis
# 10.1016/j.frl.2025.108489                                                          BERT; Crash risk; Large language model; Readability; Text analysis
# 10.1007/s12525-025-00815-6       Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
# ...                                                                                                                                               ...
# 10.18653/v1/d15-1184                                                                                                                              NaN
# 10.1214/14-AOS1250                                                     Itô semimartingale; Lévy process; Microstructure noise; Timechange; Volatility
# 10.1016/j.egypro.2014.02.176                                  Dynamic simulation; Solar access; Solar Potential; Urban densification and preservation
# 2-s2.0-84871531453            Financial markets; Generative models; Model selection; Neural networks; Non-parametric methods; Probability forecasting
# 10.1108/02686900610705037                                                                            Auditing; Auditors; Stock markets; Stock returns
#
#                               Origin
# ID
# 10.1007/978-981-96-6291-3_3   Scopus
# 10.1016/j.eswa.2025.128676    Scopus
# 10.1186/s40854-025-00789-6    Scopus
# 10.1016/j.frl.2025.108489     Scopus
# 10.1007/s12525-025-00815-6    Scopus
# ...                              ...
# 10.18653/v1/d15-1184          Scopus
# 10.1214/14-AOS1250            Scopus
# 10.1016/j.egypro.2014.02.176  Scopus
# 2-s2.0-84871531453            Scopus
# 10.1108/02686900610705037     Scopus
#
# [251 rows x 5 columns]

# %% [markdown]
# ## 1.2 Web of Science

# %%
WoS_df = pd.read_csv("WoS.csv")
WoS_df
# Out:
#     PT  \
# 0    C
# 1    J
# 2    J
# 3    C
# 4    J
# ..  ..
# 143  C
# 144  J
# 145  J
# 146  C
# 147  J
#
#                                                                                                                    AU  \
# 0                                                                                                            Gopal, A
# 1                                                                                 Carvajal-Patiño, D; Ramos-Pollán, R
# 2                                                                               Ul Haq, A; Zeb, A; Lei, ZF; Zhang, DF
# 3                                                                                                            Wang, ZH
# 4                                                                                  Tai, WX; Zhong, T; Mo, YH; Zhou, F
# ..                                                                                                                ...
# 143                                                                                                 Yuan, J; Zhang, Z
# 144                                                                         Hoang, SD; Nguyen, THH; Dey, SK; Thu, HDT
# 145                                                                                                 Ante, L; Saggu, A
# 146  Alizadeh, M; Asgari, Y; Samei, Z; Yari, S; Dehghani, S; Kubli, M; Zare, D; Bermeo, JD; Batzdorfer, V; Gilardi, F
# 147                                                                        Li, ZL; Li, ZY; Bai, T; Huang, Y; Chen, SL
#
#      BA                                    BE                         GP  \
# 0   NaN                                   NaN  ASSOC COMPUTING MACHINERY
# 1   NaN                                   NaN                        NaN
# 2   NaN                                   NaN                        NaN
# 3   NaN                                   NaN                       IEEE
# 4   NaN                                   NaN                        NaN
# ..   ..                                   ...                        ...
# 143 NaN                                   NaN                        ACM
# 144 NaN                                   NaN                        NaN
# 145 NaN                                   NaN                        NaN
# 146 NaN  Aiello, LM; Chakraborty, T; Gaito, S                        NaN
# 147 NaN                                   NaN                        NaN
#
#                                                                                                                           AF  \
# 0                                                                                                            Gopal, Achintya
# 1                                                                                Carvajal-Patino, Daniel; Ramos-Pollan, Raul
# 2                                                                      Ul Haq, Anwar; Zeb, Adnan; Lei, Zhenfeng; Zhang, Defu
# 3                                                                                                               Wang Zhuohan
# 4                                                                             Tai, Wenxin; Zhong, Ting; Mo, Yuhua; Zhou, Fan
# ..                                                                                                                       ...
# 143                                                                                                    Yuan, Jie; Zhang, Zhu
# 144                                           Hoang, Sinh Duc; Nguyen, Tho Huu-Hoang; Dey, Sandeep Kumar; Thi Thu, Hang Dang
# 145                                                                                               Ante, Lennart; Saggu, Aman
# 146  Alizadeh, Meysam; Asgari, Yasaman; Samei, Zeynab; Yari, Sara; Dehghani, Shirin; Kubli, Mael; Zare, Darya; Bermeo, Ju...
# 147                                                              Li, Zelin; Li, Zhiyong; Bai, Tao; Huang, Yin; Chen, Shaolei
#
#      BF  CA  \
# 0   NaN NaN
# 1   NaN NaN
# 2   NaN NaN
# 3   NaN NaN
# 4   NaN NaN
# ..   ..  ..
# 143 NaN NaN
# 144 NaN NaN
# 145 NaN NaN
# 146 NaN NaN
# 147 NaN NaN
#
#                                                                                                                           TI  \
# 0                                         NeuralFactors: A Novel Factor Learning Approach to Generative Modeling of Equities
# 1                    Synthetic data generation with deep generative models to enhance predictive tasks in trading strategies
# 2                                       Forecasting daily stock trend using multi-filter feature selection and deep learning
# 3                                                     TABNET WITH DATA AUGMENTATION APPORACH IN STOCK RETURN PREDICTION TASK
# 4                            Learning Sentimental and Financial Signals With Normalizing Flows for Stock Movement Prediction
# ..                                                                                                                       ...
# 143                                             Connecting The Dots: Forecasting and Explaining Short-Term Market Volatility
# 144                                                     Beyond the hype: AI advice and investor dissonance in crypto trading
# 145             Quantifying a firm's AI engagement: Constructing objective, data-driven, AI stock indices using 10-K filings
# 146          Exploring Relationships Between Cryptocurrency News Outlets and Influencers' Twitter Activity and Market Prices
# 147  Contract sentence-level evaluation (Con-SEN): A sentence-level semantic engine for accurate recognition of financial...
#
#                                                                                                                         SO  \
# 0                                                            5TH ACM INTERNATIONAL CONFERENCE ON AI IN FINANCE, ICAIF 2024
# 1                                                                           RESEARCH IN INTERNATIONAL BUSINESS AND FINANCE
# 2                                                                                         EXPERT SYSTEMS WITH APPLICATIONS
# 3    2022 19TH INTERNATIONAL COMPUTER CONFERENCE ON WAVELET ACTIVE MEDIA TECHNOLOGY AND INFORMATION PROCESSING (ICCWAMTIP)
# 4                                                                                           IEEE SIGNAL PROCESSING LETTERS
# ..                                                                                                                     ...
# 143                                                        FIRST ACM INTERNATIONAL CONFERENCE ON AI IN FINANCE, ICAIF 2020
# 144                                                                                                     CURRENT PSYCHOLOGY
# 145                                                                            TECHNOLOGICAL FORECASTING AND SOCIAL CHANGE
# 146                                                                 SOCIAL NETWORKS ANALYSIS AND MINING, ASONAM 2024, PT I
# 147                                                                         INTERNATIONAL JOURNAL OF FINANCIAL ENGINEERING
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 143  ...
# 144  ...
# 145  ...
# 146  ...
# 147  ...
#
#                                                                                                                           WC  \
# 0                                                        Business, Finance; Computer Science, Interdisciplinary Applications
# 1                                                                                                          Business, Finance
# 2    Computer Science, Artificial Intelligence; Engineering, Electrical & Electronic; Operations Research & Management Sc...
# 3                              Computer Science, Information Systems; Computer Science, Theory & Methods; Telecommunications
# 4                                                                                       Engineering, Electrical & Electronic
# ..                                                                                                                       ...
# 143                                                             Business, Finance; Computer Science, Artificial Intelligence
# 144                                                                                            Psychology, Multidisciplinary
# 145                                                                                      Business; Regional & Urban Planning
# 146  Computer Science, Artificial Intelligence; Computer Science, Information Systems; Communication; Computer Science, I...
# 147                                                                                                        Business, Finance
#
#                                                                                                                           WE  \
# 0    Conference Proceedings Citation Index - Science (CPCI-S); Conference Proceedings Citation Index - Social Science &am...
# 1                                                                                       Social Science Citation Index (SSCI)
# 2                                       Science Citation Index Expanded (SCI-EXPANDED); Social Science Citation Index (SSCI)
# 3                                                                   Conference Proceedings Citation Index - Science (CPCI-S)
# 4                                                                             Science Citation Index Expanded (SCI-EXPANDED)
# ..                                                                                                                       ...
# 143  Conference Proceedings Citation Index - Science (CPCI-S); Conference Proceedings Citation Index - Social Science &am...
# 144                                                                                     Social Science Citation Index (SSCI)
# 145                                                                                     Social Science Citation Index (SSCI)
# 146  Conference Proceedings Citation Index - Science (CPCI-S); Conference Proceedings Citation Index - Social Science &am...
# 147                                                                                   Emerging Sources Citation Index (ESCI)
#
#                                                                           SC  \
# 0                                     Business & Economics; Computer Science
# 1                                                       Business & Economics
# 2    Computer Science; Engineering; Operations Research & Management Science
# 3                                       Computer Science; Telecommunications
# 4                                                                Engineering
# ..                                                                       ...
# 143                                   Business & Economics; Computer Science
# 144                                                               Psychology
# 145                              Business & Economics; Public Administration
# 146                                          Computer Science; Communication
# 147                                                     Business & Economics
#
#         GA  PM               OA   HC   HP          DA                   UT
# 0    BY4IZ NaN             gold  NaN  NaN  2025-10-12  WOS:001443057200012
# 1    5R8LB NaN              NaN  NaN  NaN  2025-10-12  WOS:000874755600008
# 2    QB6ML NaN              NaN  NaN  NaN  2025-10-12  WOS:000614253600001
# 3    BU7AE NaN              NaN  NaN  NaN  2025-10-12  WOS:000932922500101
# 4    YP1EH NaN              NaN  NaN  NaN  2025-10-12  WOS:000748371000034
# ..     ...  ..              ...  ...  ...         ...                  ...
# 143  BY5XH NaN             gold  NaN  NaN  2025-10-12  WOS:001467563200004
# 144  1XZ5B NaN              NaN  NaN  NaN  2025-10-12  WOS:001404832400001
# 145  T0N5U NaN  Green Submitted  NaN  NaN  2025-10-12  WOS:001402083300001
# 146  BY4PF NaN              NaN  NaN  NaN  2025-10-12  WOS:001447238900028
# 147  6WA8R NaN              NaN  NaN  NaN  2025-10-12  WOS:001563374700001
#
# [148 rows x 71 columns]

# %%
clean_WoS_df = WoS_df[["UT", "TI", "AB", "DI", "DE"]].set_index("UT")
clean_WoS_df.columns = ["Title", "Abstract", "DOI", "Keywords"]
clean_WoS_df["Origin"] = "WoS"
clean_WoS_df.index.name = "ID"
clean_WoS_df
# Out:
#                                                                                                                                        Title  \
# ID
# WOS:001443057200012                                       NeuralFactors: A Novel Factor Learning Approach to Generative Modeling of Equities
# WOS:000874755600008                  Synthetic data generation with deep generative models to enhance predictive tasks in trading strategies
# WOS:000614253600001                                     Forecasting daily stock trend using multi-filter feature selection and deep learning
# WOS:000932922500101                                                   TABNET WITH DATA AUGMENTATION APPORACH IN STOCK RETURN PREDICTION TASK
# WOS:000748371000034                          Learning Sentimental and Financial Signals With Normalizing Flows for Stock Movement Prediction
# ...                                                                                                                                      ...
# WOS:001467563200004                                             Connecting The Dots: Forecasting and Explaining Short-Term Market Volatility
# WOS:001404832400001                                                     Beyond the hype: AI advice and investor dissonance in crypto trading
# WOS:001402083300001             Quantifying a firm's AI engagement: Constructing objective, data-driven, AI stock indices using 10-K filings
# WOS:001447238900028          Exploring Relationships Between Cryptocurrency News Outlets and Influencers' Twitter Activity and Market Prices
# WOS:001563374700001  Contract sentence-level evaluation (Con-SEN): A sentence-level semantic engine for accurate recognition of financial...
#
#                                                                                                                                     Abstract  \
# ID
# WOS:001443057200012  The use of machine learning for statistical modeling (and thus, generative modeling) has grown in popularity with th...
# WOS:000874755600008  This work develops machine learning (ML) predictive models on price signals for financial instruments and their inte...
# WOS:000614253600001  Stock market forecasting has attracted significant attention mainly due to the potential monetary benefits. Predicti...
# WOS:000932922500101  Despite the advent of deep learning, stock return prediction task still has many challenges. Due to the scarcity of ...
# WOS:000748371000034  Stockmovement prediction using Tweets (text) and historical price signals (time series) remains a challenging task d...
# ...                                                                                                                                      ...
# WOS:001467563200004  Market volatility prediction is of significant theoretical and practical importance in the financial market, and the...
# WOS:001404832400001  This study examines the impact of cognitive dissonance on the relationship between investors' intentions to use AI a...
# WOS:001402083300001  This paper proposes an objective, data-driven approach using natural language processing (NLP) techniques to classif...
# WOS:001447238900028  Academics increasingly acknowledge the predictive power of social media for a wide variety of events and, more speci...
# WOS:001563374700001  Financial contracts under regulatory review are often characterized by excessive length, intricate clause nesting, i...
#
#                                                       DOI  \
# ID
# WOS:001443057200012               10.1145/3677052.3698647
# WOS:000874755600008           10.1016/j.ribaf.2022.101747
# WOS:000614253600001            10.1016/j.eswa.2020.114444
# WOS:000932922500101  10.1109/ICCWAMTIP56608.2022.10016580
# WOS:000748371000034              10.1109/LSP.2021.3135793
# ...                                                   ...
# WOS:001467563200004               10.1145/3383455.3422518
# WOS:001404832400001            10.1007/s12144-025-07430-w
# WOS:001402083300001        10.1016/j.techfore.2024.123965
# WOS:001447238900028          10.1007/978-3-031-78541-2_28
# WOS:001563374700001             10.1142/S2424786325500161
#
#                                                                                                                                     Keywords  \
# ID
# WOS:001443057200012  Stock Returns; Generative Modeling; Variational Autoencoders; Statistical Factors; Risk Forecasting; Portfolio Optim...
# WOS:000874755600008         Trading strategies; Machine learning; Synthetic data; Deep generative models; Deep learning; Trading simulations
# WOS:000614253600001                                               Stock trend prediction; Feature selection; Deep learning; Machine learning
# WOS:000932922500101  Stock Return Prediction; Deep Learning; Small Dataset Problem; Conditional Tabular Generative Adversarial Network; T...
# WOS:000748371000034  Predictive models; Time series analysis; Stochastic processes; Data models; Noise measurement; Task analysis; Social...
# ...                                                                                                                                      ...
# WOS:001467563200004                                       market volatility; neural networks; forecasting; attention mechanisms; explanation
# WOS:001404832400001                             Artificial intelligence; Cognitive dissonance; Investment behaviour; Cryptocurrency; ChatGPT
# WOS:001402083300001  Artificial intelligence; Market efficiency; Natural language processing; Corporate disclosures; Exchange-traded fund...
# WOS:001447238900028                                                    Social Prediction; NLP; LLM; Prompt Engineering; Time Series Analysis
# WOS:001563374700001  Sentence-level semantic modeling; structure-aware encoding; multi-task learning; long-document processing; financial...
#
#                     Origin
# ID
# WOS:001443057200012    WoS
# WOS:000874755600008    WoS
# WOS:000614253600001    WoS
# WOS:000932922500101    WoS
# WOS:000748371000034    WoS
# ...                    ...
# WOS:001467563200004    WoS
# WOS:001404832400001    WoS
# WOS:001402083300001    WoS
# WOS:001447238900028    WoS
# WOS:001563374700001    WoS
#
# [148 rows x 5 columns]

# %% [markdown]
# ## 1.3 IEEE

# %%
ieee_df = pd.read_csv("IEEE.csv")
ieee_df
# Out:
#                                                                                                               Document Title  \
# 0                                               Large Language Models for Financial Aid in Financial Time-series Forecasting
# 1                                              Estimating Value at Risk for Central Counterparties: A Generative AI Approach
# 2                                A Comparative Study of Sequential Deep Learning Models in Financial Time Series Forecasting
# 3                                                              Stock Market Forecasting with Pretrained Deep Learning Models
# 4    Enhanced Stock Market Trend Prediction on the Indonesia Stock Exchange Using Improved Bacterial Foraging Optimizatio...
# ..                                                                                                                       ...
# 100                                                               Intrinsic Graph Structure Estimation Using Graph Laplacian
# 101                             Solution Probing Attack Against Coin Mixing Based Privacy-Preserving Crowdsourcing Platforms
# 102                   Artificial Intelligence Based Fraud Detection, Data Security and Privacy for Telecommunication Systems
# 103                                   LLMCatalyst: A Novel Incentive Mechanism for Client-Assisted Foundation Model Training
# 104                    Retraction Notice: Automated AI - Equity Market Lead–Lag Prediction Based on Multivariate Time Series
#
#                                                                                           Authors  \
# 0                                                     M. K. Islam; A. Karmacharya; T. Sue; J. Fox
# 1                                                    S. Udeshika Munasinghe; R. Rafeh; S. Rauchas
# 2                                                J. Fang; Z. Xiao; Y. Wu; J. Zhang; Z. Xu; Z. Mai
# 3                                                                S. T. Do; A. Chu; Y. Zhao; Y. Li
# 4    D. Kumar; P. Pramod Pawar; M. Kumar Meesala; P. Kumar Pareek; S. Reddy Addula; K. S. Shwetha
# ..                                                                                            ...
# 100                                             A. Noda; H. Hino; M. Tatsuno; S. Akaho; N. Murata
# 101                                                  Y. Mao; Z. Dang; H. Wang; Y. Zhang; S. Zhong
# 102                                                          K. Prabhu Rajasekar; D. Vezhaventhan
# 103                                                      R. Zeng; M. Zhao; J. Han; Y. Bi; X. Wang
# 104                          N. Satish; V. Logeswari; S. Pundir; A. Kumar; N. M.Y; N. D. Saldahna
#
#                                                                                                          Author Affiliations  \
# 0    Computer Science Department, University of Virginia; Computer Science Department, University of Virginia; Computer S...
# 1    Department of Computing Goldsmith, University of London, London, United Kingdom; School of Information Technology, C...
# 2    Independent Researcher; University of North Texas; Meta; Taylor University; Hewlett Packard Enterprise; I-66 Express...
# 3    Department of Computer and Information Sciences, Fordham University, Bronx, NY, USA; Department of Computer Science,...
# 4    Department of Information Technology, University of the Cumberlands, Williamsburg, USA; Department of Information Te...
# ..                                                                                                                       ...
# 100  School of Science and Engineering, Waseda University, Shinjuku, Tokyo 169-8555, Japan a24.noda@fuji.waseda.jp; Depar...
# 101  State Key Laboratory for Novel Software Technology, Nanjing University, Nanjing, China; State Key Laboratory for Nov...
# 102  School of Law, Specialization: Cyber Crime and Cyber Law, Saveetha University (SIMATS DEEMED UNIVERSITY), Chennai, I...
# 103  Software College, Northeastern University; Software College, Northeastern University; Software College, Northeastern...
# 104  Department of Information Technology, Mahendra Institute of Technology (Autonomous), Namakkal; Department of Electro...
#
#                                                                                                            Publication Title  \
# 0                                                                   2024 IEEE International Conference on Big Data (BigData)
# 1                                                2024 International Conference on Data Science and Its Applications (ICoDSA)
# 2                                        2024 11th International Conference on Soft Computing & Machine Intelligence (ISCMI)
# 3    2025 IEEE 11th International Conference on Big Data Computing Service and Machine Learning Applications (BigDataServ...
# 4                                2024 International Conference on Integrated Intelligence and Communication Systems (ICIICS)
# ..                                                                                                                       ...
# 100                                                                                                       Neural Computation
# 101                                                                     IEEE Transactions on Dependable and Secure Computing
# 102                                                  2024 4th International Conference on Sustainable Expert Systems (ICSES)
# 103                                                 2025 IEEE/ACM 33rd International Symposium on Quality of Service (IWQoS)
# 104                    2023 International Conference on Advances in Computing, Communication and Applied Informatics (ACCAI)
#
#     Date Added To Xplore  Publication Year Volume  Issue  Start Page  \
# 0            16 Jan 2025              2024    NaN    NaN        4892
# 1             5 Sep 2024              2024    NaN    NaN         305
# 2            28 Jan 2025              2024    NaN    NaN          22
# 3             1 Sep 2025              2025    NaN    NaN         142
# 4             5 Feb 2025              2024    NaN    NaN           1
# ..                   ...               ...    ...    ...         ...
# 100          17 Jul 2014              2014   26.0    7.0        1455
# 101           3 Sep 2024              2024   21.0    5.0        4684
# 102           3 Dec 2024              2024    NaN    NaN         402
# 103           9 Sep 2025              2025    NaN    NaN           1
# 104           2 Oct 2024              2023    NaN    NaN           1
#
#      End Page  ... Mesh_Terms Article Citation Count Patent Citation Count  \
# 0        4895  ...        NaN                    1.0                   NaN
# 1         310  ...        NaN                    1.0                   NaN
# 2          26  ...        NaN                    1.0                   NaN
# 3         146  ...        NaN                    NaN                   NaN
# 4           8  ...        NaN                    1.0                   NaN
# ..        ...  ...        ...                    ...                   ...
# 100      1483  ...        NaN                    1.0                   NaN
# 101      4698  ...        NaN                    2.0                   NaN
# 102       406  ...        NaN                    NaN                   NaN
# 103        10  ...        NaN                    NaN                   NaN
# 104         1  ...        NaN                    NaN                   NaN
#
#     Reference Count License  Online Date Issue Date Meeting Date  Publisher  \
# 0              24.0    IEEE  16 Jan 2025        NaN          NaN       IEEE
# 1              16.0    IEEE   5 Sep 2024        NaN          NaN       IEEE
# 2              32.0    IEEE  28 Jan 2025        NaN          NaN       IEEE
# 3              26.0    IEEE   1 Sep 2025        NaN          NaN       IEEE
# 4              26.0    IEEE   5 Feb 2025        NaN          NaN       IEEE
# ..              ...     ...          ...        ...          ...        ...
# 100             NaN     NaN  17 Jul 2014        NaN          NaN  MIT Press
# 101            40.0    IEEE  18 Jan 2024        NaN          NaN       IEEE
# 102            21.0    IEEE   3 Dec 2024        NaN          NaN       IEEE
# 103            33.0    IEEE   9 Sep 2025        NaN          NaN       IEEE
# 104             NaN    IEEE   2 Oct 2024        NaN          NaN       IEEE
#
#      Document Identifier
# 0       IEEE Conferences
# 1       IEEE Conferences
# 2       IEEE Conferences
# 3       IEEE Conferences
# 4       IEEE Conferences
# ..                   ...
# 100   MIT Press Journals
# 101        IEEE Journals
# 102     IEEE Conferences
# 103     IEEE Conferences
# 104     IEEE Conferences
#
# [105 rows x 28 columns]

# %%
clean_ieee_df = ieee_df[["DOI", "Document Title", "Abstract"]].copy()
clean_ieee_df.columns = ["DOI", "Title", "Abstract"]
clean_ieee_df["Keywords"] = ieee_df["IEEE Terms"].str.cat(ieee_df["Author Keywords"], sep=";")
clean_ieee_df["ID"] = ieee_df["PDF Link"]
clean_ieee_df = clean_ieee_df.set_index("ID")
clean_ieee_df["Origin"] = "IEEE"
clean_ieee_df.index.name = "ID"
clean_ieee_df
# Out:
#                                                                                                   DOI  \
# ID
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10824953      10.1109/BigData62323.2024.10824953
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10652178       10.1109/ICoDSA62899.2024.10652178
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10851487        10.1109/ISCMI63661.2024.10851487
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11129507  10.1109/BigDataService65758.2025.00026
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10859808       10.1109/ICIICS63763.2024.10859808
# ...                                                                                               ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6855483                     10.1162/NECO_a_00603
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10404041               10.1109/TDSC.2024.3355453
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10763168        10.1109/ICSES63445.2024.10763168
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11143425        10.1109/IWQoS65803.2025.11143425
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10703702        10.1109/ACCAI58221.2023.10703702
#
#                                                                                                                                                                                  Title  \
# ID
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10824953                                             Large Language Models for Financial Aid in Financial Time-series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10652178                                            Estimating Value at Risk for Central Counterparties: A Generative AI Approach
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10851487                              A Comparative Study of Sequential Deep Learning Models in Financial Time Series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11129507                                                            Stock Market Forecasting with Pretrained Deep Learning Models
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10859808  Enhanced Stock Market Trend Prediction on the Indonesia Stock Exchange Using Improved Bacterial Foraging Optimizatio...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6855483                                                                Intrinsic Graph Structure Estimation Using Graph Laplacian
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10404041                             Solution Probing Attack Against Coin Mixing Based Privacy-Preserving Crowdsourcing Platforms
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10763168                   Artificial Intelligence Based Fraud Detection, Data Security and Privacy for Telecommunication Systems
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11143425                                   LLMCatalyst: A Novel Incentive Mechanism for Client-Assisted Foundation Model Training
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10703702                    Retraction Notice: Automated AI - Equity Market Lead–Lag Prediction Based on Multivariate Time Series
#
#                                                                                                                                                                               Abstract  \
# ID
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10824953  Considering the difficulty of financial time series forecasting in financial aid, much of the current research focus...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10652178  Central counterparties (CCPs) play an important role in the stability of financial markets by helping to mitigate sy...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10851487  Time series analysis of daily stock prices is challenging due to the inherent complexity, nonlinearity, and nonstati...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11129507  To perform stock market-related forecasting, we developed a synchronized framework that employs pretrained deep lear...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10859808  It was difficult to find low-risk firms in 2022 due to the large number of 825 listed on the Indonesia Stock Exchang...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6855483   A graph is a mathematical representation of a set of variables where some pairs of the variables are connected by ed...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10404041  Conventional crowdsourcing platforms primarily rely on a central server as the broker for information exchange. Alth...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10763168  Globally, fraud is increasing and has the potential to cost firms billions of dollars and inflict serious financial ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11143425  Large foundation models, such as SORA and GPT-4, have emerged as a mainstream and promising trend in the deep learni...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10703702  The lead-lag structure among time-series factors is the recognition that in multivariate time-series frameworks, som...
#
#                                                                                                                                                                               Keywords  \
# ID
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10824953  Runtime;Time series analysis;Memory management;Predictive models;Big Data;Transformers;Market research;Data models;F...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10652178  Reactive power;Generative AI;Computational modeling;Stability criteria;Estimation;Predictive models;Generative adver...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10851487  Measurement;Deep learning;Accuracy;Large language models;Time series analysis;Predictive models;Transformers;Forecas...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11129507  Deep learning;Analytical models;Sentiment analysis;Social networking (online);Time series analysis;Predictive models...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10859808  Microorganisms;Spirals;Predictive models;Feature extraction;Market research;Prediction algorithms;Whale optimization...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6855483                                                                                                                       NaN
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10404041  Crowdsourcing;Task analysis;Blockchains;Encryption;Data models;Smart contracts;Estimation;Crowdsourcing security;pro...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10763168  Technological innovation;Consumer behavior;Banking;Media;Real-time systems;Robustness;Fraud;Telecommunications;Senso...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11143425  Training;Procurement;Costs;Foundation models;Biological system modeling;Transforms;Quality of service;Approximation ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10703702                                                                                                                      NaN
#
#                                                               Origin
# ID
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10824953   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10652178   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10851487   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11129507   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10859808   IEEE
# ...                                                              ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6855483    IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10404041   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10763168   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11143425   IEEE
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10703702   IEEE
#
# [105 rows x 5 columns]

# %% [markdown]
# ## 1.4 ProQuest

# %%
proquest_df = pd.read_csv("ProQuest.csv")
proquest_df
# Out:
#                                                                                                                       Title  \
# 0               The power of ChatGPT in processing text: Evidence from analysis and prediction in the exchange rate markets
# 1                        Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
# 2    Detecting Bitcoin Sentiment: Leveraging Language Model Applications in Sentiment Analysis for Bitcoin Price Prediction
# 3   The <i>supply chain capitalism of AI</i>: a call to (re)think algorithmic harms and resistance through environmental...
# 4                        Modeling Asset Price Process: An Approach for Imaging Price Chart with Generative Diffusion Models
# ..                                                                                                                      ...
# 93                                                     Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 94                                                     Bayesian online learning of the hazard rate in change-point problems
# 95                                                     Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 96                                   The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
# 97                                   The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
#
#                                                                                                                    Abstract  \
# 0   This study investigates the application of large language models in analyzing sentiment features within the exchange...
# 1   The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
# 2   As Bitcoin continues to establish itself as a global asset and discussions around relevant regulations become more a...
# 3   Artificial Intelligence (AI) is woven into a supply chain of capital, commodities and human labour that has been neg...
# 4   Artificial Intelligence (AI) models have been recently studied to discover data patterns for prediction and forecast...
# ..                                                                                                                      ...
# 93  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 94  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 95  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 96  Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
# 97  Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
#
#        StoreId          AccessionNumber         ArticleType  \
# 0   3253199750                      NaN  Scholarly Journals
# 1   3229330841                      NaN  Scholarly Journals
# 2   3241056936                      NaN  Scholarly Journals
# 3   3258102981                      NaN  Scholarly Journals
# 4   3232240735                      NaN  Scholarly Journals
# ..         ...                      ...                 ...
# 93   754897843                 13537051  Scholarly Journals
# 94   748943350                 20569174  Scholarly Journals
# 95   742446133                      NaN  Scholarly Journals
# 96    32987886   200903-B7-0043220 (MB)  Scholarly Journals
# 97    31032393    200801-B7-019325 (MB)  Scholarly Journals
#
#                                                                                                           AuthorAffiliation  \
# 0    Yunnan University of Finance and Economics, School of Economics, Kunming, China (GRID:grid.464506.5) (ISNI:0000 000...
# 1    University of Cologne, Cologne, Germany (GRID:grid.6190.e) (ISNI:0000 0000 8580 3777) , University of Cologne, Colo...
# 2    Seoul National University, Advanced Institute of Convergence Technology, Suwon-si, Korea (GRID:grid.31501.36) (ISNI...
# 3    Oxford Internet Institute (University of Oxford), Oxford, UK; UCL Centre for Capitalism Studies, University College...
# 4    Seoul National University, Department of Industrial Engineering, Seoul, South Korea (GRID:grid.31501.36) (ISNI:0000...
# ..                                                                                                                      ...
# 93                                                                                                                      NaN
# 94                                                                                                                      NaN
# 95                                                                                                                      NaN
# 96                                                                                                                      NaN
# 97                                                                                                                      NaN
#
#                                                     Authors    coden  \
# 0          Yang, Kun;Deng, Ruxin;Wei, Yunjie;Wang, Shouyang      NaN
# 1   Haase, Frederic;Celig, Tom;Rath, Oliver;Schoder, Detlef      NaN
# 2                   Jung, Hae Sun;Lee, Haein;Kim, Jang Hyun      NaN
# 3                                             Valdivia, Ana      NaN
# 4                  Park, Jinseong;Ko, Hyungjin;Lee, Jaewook      NaN
# ..                                                      ...      ...
# 93        Wilson, Robert C;Nassar, Matthew R;Gold, Joshua I      NaN
# 94        Wilson, Robert C;Nassar, Matthew R;Gold, Joshua I      NaN
# 95        Wilson, Robert C;Nassar, Matthew R;Gold, Joshua I   NEUCEB
# 96                                Liu, Carol;Nabar, Sandeep      NaN
# 97                                Liu, Carol;Nabar, Sandeep      NaN
#
#    companies  \
# 0     OpenAI
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 93       NaN
# 94       NaN
# 95       NaN
# 96       NaN
# 97       NaN
#
#                                                                                                                   copyright  \
# 0    © The Author(s) 2025. This work is published under http://creativecommons.org/licenses/by/4.0/ (the “License”). Not...
# 1    © The Author(s) 2025. This work is published under http://creativecommons.org/licenses/by/4.0/ (the “License”). Not...
# 2    © The Author(s) 2025. This work is published under http://creativecommons.org/licenses/by-nc-nd/4.0/ (the “License”...
# 3    © 2024 The Author(s). Published by Informa UK Limited, trading as Taylor & Francis Group. This work is licensed und...
# 4    © The Author(s) 2024. This work is published under http://creativecommons.org/licenses/by/4.0/ (the “License”). Not...
# ..                                                                                                                      ...
# 93                                                                                                                      NaN
# 94                                                                                                                      NaN
# 95                                                                                    Copyright MIT Press Journals Sep 2010
# 96                                                                                                                      NaN
# 97                                                                                                                      NaN
#
#     ...                               majorClassificationCodes  \
# 0   ...                                                    NaN
# 1   ...       52394 Portfolio Management and Investment Advice
# 2   ...                                                    NaN
# 3   ...                                                    NaN
# 4   ...                                                    NaN
# ..  ...                                                    ...
# 93  ...      N3 11002 Computational & theoretical neuroscience
# 94  ...                                                    NaN
# 95  ...                                                    NaN
# 96  ...   B7 Management, Training, Regulations, Marketing (MB)
# 97  ...   B7 Management, Training, Regulations, Marketing (MB)
#
#                                                                          notes  \
# 0    2025-09-08 (Registration) , 2024-07-22 (Received) , 2025-09-05 (Accepted)
# 1    2025-06-25 (Registration) , 2025-01-19 (Received) , 2025-06-25 (Accepted)
# 2                            2025-07-12 (Registration) , 2025-07-12 (Accepted)
# 3                                2024-04-04 (Received) , 2024-09-10 (Accepted)
# 4                            2024-06-19 (Registration) , 2024-06-18 (Accepted)
# ..                                                                         ...
# 93                                                                         NaN
# 94                                  Print , Internet , Indexing method: Manual
# 95                                                                         NaN
# 96                                                                         NaN
# 97                                                                         NaN
#
#    startPage                                 subjectClassifications  \
# 0        118                                                    NaN
# 1         64       52394 Portfolio Management and Investment Advice
# 2         77                                                    NaN
# 3       2118                                                    NaN
# 4        349                                                    NaN
# ..       ...                                                    ...
# 93      2452      N3 11002 Computational & theoretical neuroscience
# 94      2452                                                    NaN
# 95      2452                                                    NaN
# 96       948   B7 Management, Training, Regulations, Marketing (MB)
# 97       948   B7 Management, Training, Regulations, Marketing (MB)
#
#                                                           subjectHeadings  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
# ..                                                                    ...
# 93                                                                    NaN
# 94   Algorithms , Humans , Learning , Bayes Theorem , Models, Statistical
# 95                                                                    NaN
# 96                                                                    NaN
# 97                                                                    NaN
#
#                                                                                                                subjectTerms  \
# 0    Language , Accuracy , Technological change , PSYCHOLOGY , Trends , ECONOMICS , SUSTAINABILITY , FINANCE , Text anal...
# 1    Social networks , FINANCE , Decentralization , PSYCHOLOGY , ECONOMICS , Financial information , SUSTAINABILITY , Di...
# 2    Language , Accuracy , Dictionaries , Deep learning , Performance evaluation , Trends , PSYCHOLOGY , ECONOMICS , Pri...
# 3    Artificial intelligence , Algorithms , Supply , Commodities , Resistance , Extraction , SUSTAINABILITY , Capitalism...
# 4    Artificial intelligence , Finance , SUSTAINABILITY , FINANCE , Finance , Diffusion models , Deep learning , Random ...
# ..                                                                                                                      ...
# 93                   Learning , Mathematical models , Data processing , Bayesian analysis , Brain , EEG , Internet , Models
# 94                                                                                                            Index Medicus
# 95     Bayesian analysis , Online instruction , Distance learning , Brain , Information processing , Electroencephalography
# 96   Raw materials , Consulting , Mathematical models , Sales , Perception , Marketing , Clients , Accounting , Error an...
# 97   Raw materials , Consulting , Mathematical models , Sales , Marketing , Clients , Accounting , Error analysis , Mana...
#
#                                                                                                                    subjects  \
# 0    KeywordsChatGPT , Sentiment analysis , Exchange rate , Topic analysis , Interval , Economics , Applied Economics , ...
# 1    KeywordsSocial media signals , Cryptocurrencies , Collective intelligence , Trading signals , Predictive power , Wi...
# 2                            Large language models , Sentiment analysis , Time series analysis , Bitcoin , Price prediction
# 3                                               Supply chain , AI , capitalism , infrastructure , environment , data centre
# 4    KeywordsDeep learning , Generative diffusion model , Asset price process , Financial simulation , Price chart , Opt...
# ..                                                                                                                      ...
# 93                                                                                                                      NaN
# 94                                                                                                                      NaN
# 95                                                                                                                      NaN
# 96                                                                                                                  Article
# 97                                                                                                                  Article
#
#                                                                              URL  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
# ..                                                                           ...
# 93                                                                           NaN
# 94                                                                           NaN
# 95                                                                           NaN
# 96   http://www.emeraldinsight.com/Insight/viewContentItem.do;jsessionid=BDB7E76
# 97                                                                           NaN
#
#                                                                                                                   FindACopy  \
# 0   https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 1   https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 2   https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 3   https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 4   https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# ..                                                                                                                      ...
# 93  https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 94  https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 95  https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 96  https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
# 97  https://bibsys-almaprimo.hosted.exlibrisgroup.com/openurl/NTNU_UB/NTNU_UB_services_page?url_ver=Z39.88-2004&amp;rft_...
#
#                                                               Database
# 0   Coronavirus Research Database, Publicly Available Content Database
# 1        SciTech Premium Collection, Social Science Premium Collection
# 2                                           SciTech Premium Collection
# 3        SciTech Premium Collection, Social Science Premium Collection
# 4        SciTech Premium Collection, Social Science Premium Collection
# ..                                                                 ...
# 93                                          SciTech Premium Collection
# 94                                          SciTech Premium Collection
# 95                                          SciTech Premium Collection
# 96                                          SciTech Premium Collection
# 97                                          SciTech Premium Collection
#
# [98 rows x 50 columns]

# %%
import numpy as np

clean_proquest_df = proquest_df[["digitalObjectIdentifier", "Title", "Abstract", "issn", "elecISSN", "StoreId"]]
clean_proquest_df.columns = ["DOI", "Title", "Abstract", "ISSN", "EISSN", "StoreId"]
clean_proquest_df["Keywords"] = proquest_df["subjectTerms"].str.cat(ieee_df["Author Keywords"], sep=";")

clean_proquest_df["ID"] = np.where(
    pd.notna(clean_proquest_df["DOI"]), clean_proquest_df["DOI"],
    np.where(
        pd.notna(clean_proquest_df["ISSN"]), clean_proquest_df["ISSN"],
        np.where(
            pd.notna(clean_proquest_df["EISSN"]), clean_proquest_df["EISSN"],
            clean_proquest_df["StoreId"]
        )
    )
)

clean_proquest_df= clean_proquest_df.drop(columns=["ISSN", "EISSN", "StoreId"])
clean_proquest_df = clean_proquest_df.set_index("ID")
clean_proquest_df["Origin"] = "Proquest"
clean_proquest_df.index.name = "ID"
clean_proquest_df
# Out:
# /var/folders/ys/h85_xrkj6ws0c8msbf39p3th0000gn/T/ipykernel_29092/2352228501.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_proquest_df["Keywords"] = proquest_df["subjectTerms"].str.cat(ieee_df["Author Keywords"], sep=";")
# /var/folders/ys/h85_xrkj6ws0c8msbf39p3th0000gn/T/ipykernel_29092/2352228501.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_proquest_df["ID"] = np.where(
#                                                          DOI  \
# ID
# 10.1186/s40854-025-00789-6        10.1186/s40854-025-00789-6
# 10.1007/s12525-025-00815-6        10.1007/s12525-025-00815-6
# 10.1007/s11063-025-11787-1        10.1007/s11063-025-11787-1
# 10.1080/1369118X.2024.2420021  10.1080/1369118X.2024.2420021
# 10.1007/s10614-024-10668-4        10.1007/s10614-024-10668-4
# ...                                                      ...
# 10.1162/NECO_a_00007                    10.1162/NECO_a_00007
# 10.1162/NECO_a_00007                    10.1162/NECO_a_00007
# 0899-7667                                                NaN
# 10.1108/02686900610705037          10.1108/02686900610705037
# 10.1108/02686900610705037          10.1108/02686900610705037
#
#                                                                                                                                                  Title  \
# ID
# 10.1186/s40854-025-00789-6                 The power of ChatGPT in processing text: Evidence from analysis and prediction in the exchange rate markets
# 10.1007/s12525-025-00815-6                          Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
# 10.1007/s11063-025-11787-1      Detecting Bitcoin Sentiment: Leveraging Language Model Applications in Sentiment Analysis for Bitcoin Price Prediction
# 10.1080/1369118X.2024.2420021  The <i>supply chain capitalism of AI</i>: a call to (re)think algorithmic harms and resistance through environmental...
# 10.1007/s10614-024-10668-4                          Modeling Asset Price Process: An Approach for Imaging Price Chart with Generative Diffusion Models
# ...                                                                                                                                                ...
# 10.1162/NECO_a_00007                                                              Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 10.1162/NECO_a_00007                                                              Bayesian online learning of the hazard rate in change-point problems
# 0899-7667                                                                         Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 10.1108/02686900610705037                                       The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
# 10.1108/02686900610705037                                       The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
#
#                                                                                                                                               Abstract  \
# ID
# 10.1186/s40854-025-00789-6     This study investigates the application of large language models in analyzing sentiment features within the exchange...
# 10.1007/s12525-025-00815-6     The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
# 10.1007/s11063-025-11787-1     As Bitcoin continues to establish itself as a global asset and discussions around relevant regulations become more a...
# 10.1080/1369118X.2024.2420021  Artificial Intelligence (AI) is woven into a supply chain of capital, commodities and human labour that has been neg...
# 10.1007/s10614-024-10668-4     Artificial Intelligence (AI) models have been recently studied to discover data patterns for prediction and forecast...
# ...                                                                                                                                                ...
# 10.1162/NECO_a_00007           Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 10.1162/NECO_a_00007           Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 0899-7667                      Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 10.1108/02686900610705037      Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
# 10.1108/02686900610705037      Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
#
#                                                                                                                                               Keywords  \
# ID
# 10.1186/s40854-025-00789-6      Language , Accuracy , Technological change , PSYCHOLOGY , Trends , ECONOMICS , SUSTAINABILITY , FINANCE , Text anal...
# 10.1007/s12525-025-00815-6      Social networks , FINANCE , Decentralization , PSYCHOLOGY , ECONOMICS , Financial information , SUSTAINABILITY , Di...
# 10.1007/s11063-025-11787-1      Language , Accuracy , Dictionaries , Deep learning , Performance evaluation , Trends , PSYCHOLOGY , ECONOMICS , Pri...
# 10.1080/1369118X.2024.2420021   Artificial intelligence , Algorithms , Supply , Commodities , Resistance , Extraction , SUSTAINABILITY , Capitalism...
# 10.1007/s10614-024-10668-4      Artificial intelligence , Finance , SUSTAINABILITY , FINANCE , Finance , Diffusion models , Deep learning , Random ...
# ...                                                                                                                                                ...
# 10.1162/NECO_a_00007            Learning , Mathematical models , Data processing , Bayesian analysis , Brain , EEG , Internet , Models;Deep Reinfor...
# 10.1162/NECO_a_00007                                                         Index Medicus;Gamification;Machine learning;Simulation;Financial literacy
# 0899-7667                       Bayesian analysis , Online instruction , Distance learning , Brain , Information processing , Electroencephalograph...
# 10.1108/02686900610705037       Raw materials , Consulting , Mathematical models , Sales , Perception , Marketing , Clients , Accounting , Error an...
# 10.1108/02686900610705037       Raw materials , Consulting , Mathematical models , Sales , Marketing , Clients , Accounting , Error analysis , Mana...
#
#                                  Origin
# ID
# 10.1186/s40854-025-00789-6     Proquest
# 10.1007/s12525-025-00815-6     Proquest
# 10.1007/s11063-025-11787-1     Proquest
# 10.1080/1369118X.2024.2420021  Proquest
# 10.1007/s10614-024-10668-4     Proquest
# ...                                 ...
# 10.1162/NECO_a_00007           Proquest
# 10.1162/NECO_a_00007           Proquest
# 0899-7667                      Proquest
# 10.1108/02686900610705037      Proquest
# 10.1108/02686900610705037      Proquest
#
# [98 rows x 5 columns]

# %% [markdown]
# # 2. Merge and Clean data

# %%
clean_df = pd.concat([clean_scopus_df, clean_WoS_df, clean_ieee_df, clean_proquest_df])
clean_df.to_csv("before_removing.csv")
clean_df
# Out:
#                                                      DOI  \
# ID
# 10.1007/978-981-96-6291-3_3  10.1007/978-981-96-6291-3_3
# 10.1016/j.eswa.2025.128676    10.1016/j.eswa.2025.128676
# 10.1186/s40854-025-00789-6    10.1186/s40854-025-00789-6
# 10.1016/j.frl.2025.108489      10.1016/j.frl.2025.108489
# 10.1007/s12525-025-00815-6    10.1007/s12525-025-00815-6
# ...                                                  ...
# 10.1162/NECO_a_00007                10.1162/NECO_a_00007
# 10.1162/NECO_a_00007                10.1162/NECO_a_00007
# 0899-7667                                            NaN
# 10.1108/02686900610705037      10.1108/02686900610705037
# 10.1108/02686900610705037      10.1108/02686900610705037
#
#                                                                                                                                                Title  \
# ID
# 10.1007/978-981-96-6291-3_3  Stock Price Prediction Using Univariate and Multivariate Historical Data with Post-Interpretation via Large Language...
# 10.1016/j.eswa.2025.128676                                                                         In the beginning was the Word: LLM-VaR and LLM-ES
# 10.1186/s40854-025-00789-6               The power of ChatGPT in processing text: Evidence from analysis and prediction in the exchange rate markets
# 10.1016/j.frl.2025.108489                                                                Readability of financial reports and stock price crash risk
# 10.1007/s12525-025-00815-6                        Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
# ...                                                                                                                                              ...
# 10.1162/NECO_a_00007                                                            Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 10.1162/NECO_a_00007                                                            Bayesian online learning of the hazard rate in change-point problems
# 0899-7667                                                                       Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 10.1108/02686900610705037                                     The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
# 10.1108/02686900610705037                                     The stock market reaction to Ernst & Young's sale of its consulting unit to Cap Gemini
#
#                                                                                                                                             Abstract  \
# ID
# 10.1007/978-981-96-6291-3_3  In this study, we propose a hybrid approach that utilizes both univariate and multivariate historical data from key ...
# 10.1016/j.eswa.2025.128676   This study introduces LLM-VaR and LLM-ES, novel risk estimation metrics that utilize general-purpose large language ...
# 10.1186/s40854-025-00789-6   This study investigates the application of large language models in analyzing sentiment features within the exchange...
# 10.1016/j.frl.2025.108489    The rapid evolution of machine learning makes text analysis more feasible. Utilizing a large language model, BERT, t...
# 10.1007/s12525-025-00815-6   The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
# ...                                                                                                                                              ...
# 10.1162/NECO_a_00007         Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 10.1162/NECO_a_00007         Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 0899-7667                    Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 10.1108/02686900610705037    Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
# 10.1108/02686900610705037    Purpose - The purpose of this paper is to investigate how the stock prices of Ernst & Young's (E&Y's) audit clients ...
#
#                                                                                                                                             Keywords  \
# ID
# 10.1007/978-981-96-6291-3_3     Large Language Models (LLM); Multivariate Analysis; Stock Price Prediction; Time Series Forecasting; Univariate Data
# 10.1016/j.eswa.2025.128676                                            Expected shortfall; GPT; Large language models; LLM-ES; LLM-VaR; Value at risk
# 10.1186/s40854-025-00789-6                                                      ChatGPT; Exchange rate; Interval; Sentiment analysis; Topic analysis
# 10.1016/j.frl.2025.108489                                                         BERT; Crash risk; Large language model; Readability; Text analysis
# 10.1007/s12525-025-00815-6      Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
# ...                                                                                                                                              ...
# 10.1162/NECO_a_00007          Learning , Mathematical models , Data processing , Bayesian analysis , Brain , EEG , Internet , Models;Deep Reinfor...
# 10.1162/NECO_a_00007                                                       Index Medicus;Gamification;Machine learning;Simulation;Financial literacy
# 0899-7667                     Bayesian analysis , Online instruction , Distance learning , Brain , Information processing , Electroencephalograph...
# 10.1108/02686900610705037     Raw materials , Consulting , Mathematical models , Sales , Perception , Marketing , Clients , Accounting , Error an...
# 10.1108/02686900610705037     Raw materials , Consulting , Mathematical models , Sales , Marketing , Clients , Accounting , Error analysis , Mana...
#
#                                Origin
# ID
# 10.1007/978-981-96-6291-3_3    Scopus
# 10.1016/j.eswa.2025.128676     Scopus
# 10.1186/s40854-025-00789-6     Scopus
# 10.1016/j.frl.2025.108489      Scopus
# 10.1007/s12525-025-00815-6     Scopus
# ...                               ...
# 10.1162/NECO_a_00007         Proquest
# 10.1162/NECO_a_00007         Proquest
# 0899-7667                    Proquest
# 10.1108/02686900610705037    Proquest
# 10.1108/02686900610705037    Proquest
#
# [602 rows x 5 columns]

# %%
# Temporarily reset index
clean_df = clean_df.reset_index()

# Separate rows with NaN in 'DOI'
nan_rows = clean_df[clean_df['DOI'].isna()]

# Process rows where 'DOI' is not NaN
non_nan_rows = clean_df[clean_df['DOI'].notna()].copy()

# Normalize DOI
non_nan_rows["DOI"] = non_nan_rows["DOI"].str.lower()
non_nan_rows["DOI"] = non_nan_rows["DOI"].str.replace("https://doi.org/", "", regex=False)

# Drop duplicates based on DOI
non_nan_rows = non_nan_rows.drop_duplicates(subset=["DOI"], keep='first')

# Concatenate the untouched NaN rows back into the DataFrame
clean_df = pd.concat([non_nan_rows, nan_rows], ignore_index=True)

# Display the result
clean_df
# Out:
#                                                                 ID  \
# 0                                      10.1007/978-981-96-6291-3_3
# 1                                       10.1016/j.eswa.2025.128676
# 2                                       10.1186/s40854-025-00789-6
# 3                                        10.1016/j.frl.2025.108489
# 4                                       10.1007/s12525-025-00815-6
# ..                                                             ...
# 317  https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10805163
# 318  https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10647180
# 319                                                     3149090574
# 320                                                      0090-5364
# 321                                                      0899-7667
#
#                              DOI  \
# 0    10.1007/978-981-96-6291-3_3
# 1     10.1016/j.eswa.2025.128676
# 2     10.1186/s40854-025-00789-6
# 3      10.1016/j.frl.2025.108489
# 4     10.1007/s12525-025-00815-6
# ..                           ...
# 317                          NaN
# 318                          NaN
# 319                          NaN
# 320                          NaN
# 321                          NaN
#
#                                                                                                                        Title  \
# 0    Stock Price Prediction Using Univariate and Multivariate Historical Data with Post-Interpretation via Large Language...
# 1                                                                          In the beginning was the Word: LLM-VaR and LLM-ES
# 2                The power of ChatGPT in processing text: Evidence from analysis and prediction in the exchange rate markets
# 3                                                                Readability of financial reports and stock price crash risk
# 4                         Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
# ..                                                                                                                       ...
# 317                                                           Prediction of Foreign Exchange Rates by a Large Language Model
# 318                                                                   Applying Large Language Models to Issue Classification
# 319                                                           Prediction of Foreign Exchange Rates by a Large Language Model
# 320                                                                             Estimating time-changes in noisy Lévy models
# 321                                                     Bayesian Online Learning of the Hazard Rate in Change-Point Problems
#
#                                                                                                                     Abstract  \
# 0    In this study, we propose a hybrid approach that utilizes both univariate and multivariate historical data from key ...
# 1    This study introduces LLM-VaR and LLM-ES, novel risk estimation metrics that utilize general-purpose large language ...
# 2    This study investigates the application of large language models in analyzing sentiment features within the exchange...
# 3    The rapid evolution of machine learning makes text analysis more feasible. Utilizing a large language model, BERT, t...
# 4    The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
# ..                                                                                                                       ...
# 317  This paper proposes a prompt-based method utilizing a large language model (LLM) to predict changes in foreign excha...
# 318  Effective prioritization of issue reports in software engineering helps to optimize resource allocation and informat...
# 319  Conference Title: 2024 SICE Festival with Annual Conference (SICE FES) Conference Start Date: 2024, Aug. 27 Conferen...
# 320  In quantitative finance, we often model asset prices as a noisy Ito semimartingale. As this model is not identifiabl...
# 321  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
#
#                                                                                                                     Keywords  \
# 0       Large Language Models (LLM); Multivariate Analysis; Stock Price Prediction; Time Series Forecasting; Univariate Data
# 1                                             Expected shortfall; GPT; Large language models; LLM-ES; LLM-VaR; Value at risk
# 2                                                       ChatGPT; Exchange rate; Interval; Sentiment analysis; Topic analysis
# 3                                                         BERT; Crash risk; Large language model; Readability; Text analysis
# 4       Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
# ..                                                                                                                       ...
# 317  Training;Deep learning;Exchange rates;Costs;Profitability;Large language models;Time series analysis;Predictive mode...
# 318  Training;Large language models;Focusing;Training data;Standardization;Transformers;Data models;Issue Report Classifi...
# 319   Prompt engineering , Large language models , Empirical analysis , Economic;Generative Pre-trained Transformer;Optio...
# 320   Probability distribution , SUSTAINABILITY , Estimating techniques , Studies , FINANCE , SUSTAINABILITY , Approximat...
# 321   Bayesian analysis , Online instruction , Distance learning , Brain , Information processing , Electroencephalograph...
#
#        Origin
# 0      Scopus
# 1      Scopus
# 2      Scopus
# 3      Scopus
# 4      Scopus
# ..        ...
# 317      IEEE
# 318      IEEE
# 319  Proquest
# 320  Proquest
# 321  Proquest
#
# [322 rows x 6 columns]

# %%
# Show title dupes
clean_df[clean_df["Title"].duplicated(keep=False)].sort_values("Title")
# Out:
#                                     ID                                DOI  \
# 321                          0899-7667                                NaN
# 242                WOS:000280563600008               10.1162/neco_a_00007
# 156  10.18653/v1/2024.findings-acl.233  10.18653/v1/2024.findings-acl.233
# 308                WOS:001356731804003                                NaN
# 95        10.14569/IJACSA.2025.0160402       10.14569/ijacsa.2025.0160402
# ..                                 ...                                ...
# 311                WOS:000682772902030                                NaN
# 310                WOS:001502658900017                                NaN
# 94              10.3905/jpm.2025.1.710             10.3905/jpm.2025.1.710
# 8        10.1016/j.econlet.2025.112602      10.1016/j.econlet.2025.112602
# 54     10.1109/ISEC64801.2025.11147253    10.1109/isec64801.2025.11147253
#
#                                                                                                                        Title  \
# 321                                                     Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 242                                                     Bayesian Online Learning of the Hazard Rate in Change-Point Problems
# 156  Can Large Language Models Mine Interpretable Financial Factors More Effectively? A Neural-Symbolic Factor Mining Age...
# 308  Can Large Language Models Mine Interpretable Financial Factors More Effectively? A Neural-Symbolic Factor Mining Age...
# 95              Comparing Vision-Instruct LLMs, Vision-Based Deep Learning, and Numeric Models for Stock Movement Prediction
# ..                                                                                                                       ...
# 311                                            Probabilistic Analysis of Market Impact of Analysts' Recommendation Revisions
# 310                                                 Using Large Language Models to Estimate Novel Risk: Impact on Volatility
# 94                                                  Using Large Language Models to Estimate Novel Risk: Impact on Volatility
# 8                                                                                                                        NaN
# 54                                                                                                                       NaN
#
#                                                                                                                     Abstract  \
# 321  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 242  Change-point models are generative models of time-varying data in which the underlying generative parameters undergo...
# 156  Finding interpretable factors for stock returns is the most vital issue in the empirical asset pricing domain. As da...
# 308  Finding interpretable factors for stock returns is the most vital issue in the empirical asset pricing domain. As da...
# 95   This research conducts a comparative study of several stock movement prediction approaches, evaluating large languag...
# ..                                                                                                                       ...
# 311  In this paper, we propose to model the short-term impact of recommendation revisions on stock price movements in pro...
# 310  This article presents an integrated framework to estimate hard to measure (novel) financial risk for volatility fore...
# 94   This article presents an integrated framework to estimate hard to measure (novel) financial risk for volatility fore...
# 8                                                                                                    [No abstract available]
# 54                                                                                                   [No abstract available]
#
#                                                                                                                     Keywords  \
# 321   Bayesian analysis , Online instruction , Distance learning , Brain , Information processing , Electroencephalograph...
# 242                                                                                                                      NaN
# 156                                                                                                                      NaN
# 308                                                                                                                      NaN
# 95   Convolutional Neural Network (CNN); Large Language Model (LLM); MobileNetV2; stock price prediction; time series for...
# ..                                                                                                                       ...
# 311                                                    Bayesian; analyst recommendations; machine learning; trading strategy
# 310                                                                                                                      NaN
# 94                                                                                                                       NaN
# 8                                                                                                                        NaN
# 54                                                                                                                       NaN
#
#        Origin
# 321  Proquest
# 242       WoS
# 156    Scopus
# 308       WoS
# 95     Scopus
# ..        ...
# 311       WoS
# 310       WoS
# 94     Scopus
# 8      Scopus
# 54     Scopus
#
# [24 rows x 6 columns]

# %%
# Drop duplicates based on title
clean_df = clean_df.groupby(['Title'], as_index=False).first()
clean_df = clean_df.copy()
clean_df
# Out:
#                                                                                                                        Title  \
# 0                                A Comparative Study of Sequential Deep Learning Models in Financial Time Series Forecasting
# 1    A Deep Reinforcement Learning Approach for Portfolio Optimization of Brazilian Assets Using Fundamental and Sentimen...
# 2                                                                 A Financial Time Series Denoiser Based on Diffusion Models
# 3                                                                   A First Look at Financial Data Analysis Using ChatGPT-4o
# 4                                                                A Hybrid Approach on Conditional GAN for Portfolio Analysis
# ..                                                                                                                       ...
# 303                            Trend-Heuristic Reinforcement Learning Framework for News-Oriented Stock Portfolio Management
# 304                                                Using Generative AI to predict the weather impact on future stock returns
# 305                                                 Using Large Language Models to Estimate Novel Risk: Impact on Volatility
# 306                                     Utility of synthetic musculoskeletal gaits for generalizable healthcare applications
# 307                       Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
#
#                                                                 ID  \
# 0                                 10.1109/ISCMI63661.2024.10851487
# 1    https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558
# 2                                          10.1145/3677052.3698649
# 3                                             10.3390/jrfm18020099
# 4                                     10.1007/978-981-19-5845-8_61
# ..                                                             ...
# 303  https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993
# 304                                     10.1007/s11156-025-01437-x
# 305                                         10.3905/jpm.2025.1.710
# 306                                     10.1038/s41467-025-61292-1
# 307                                     10.1007/s12525-025-00815-6
#
#                                    DOI  \
# 0     10.1109/iscmi63661.2024.10851487
# 1      10.1109/compsac65507.2025.00258
# 2              10.1145/3677052.3698649
# 3                 10.3390/jrfm18020099
# 4         10.1007/978-981-19-5845-8_61
# ..                                 ...
# 303  10.1109/icassp48485.2024.10447993
# 304         10.1007/s11156-025-01437-x
# 305             10.3905/jpm.2025.1.710
# 306         10.1038/s41467-025-61292-1
# 307         10.1007/s12525-025-00815-6
#
#                                                                                                                     Abstract  \
# 0    Time series analysis of daily stock prices is challenging due to the inherent complexity, nonlinearity, and nonstati...
# 1    The Brazilian capital market presents unique challenges for portfolio optimization due to its volatility and informa...
# 2    Financial time series often exhibit low signal-to-noise ratio, posing significant challenges for accurate data inter...
# 3    OpenAI’s new flagship model, ChatGPT-4o, released on 13 May 2024, offers enhanced natural language understanding and...
# 4    Over the decades, the Markowitz framework has been used extensively in portfolio analysis though it puts too much em...
# ..                                                                                                                       ...
# 303  Recent studies have shown that reinforcement learning (RL) methods have brought significant performance gains for st...
# 304  This study explores the use of Generative AI, specifically OpenAI’s ChatGPT, for forecasting the impacts of severe w...
# 305  This article presents an integrated framework to estimate hard to measure (novel) financial risk for volatility fore...
# 306  Deep-neural-network-based artificial intelligence enables quantitative gait analysis with commodity sensors. However...
# 307  The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
#
#                                                                                                                     Keywords  \
# 0                                              Deep Learning; Finance; Large Language Model; Survey; Time Series Forecasting
# 1    Training;Sentiment analysis;Soft sensors;Software algorithms;Benchmark testing;Deep reinforcement learning;Performan...
# 2                                                                 Denoising; Diffusion Model; Financial Time Series; Trading
# 3    academia; artificial intelligence (AI); ChatGPT; data analysis; finance research; financial analysis; generative AI ...
# 4    Autoencoding conditional GAN (ACGAN); Conditional GAN; Hybrid CGAN; Markowitz framework; Portfolio analysis and allo...
# ..                                                                                                                       ...
# 303  Training;Supervised learning;Reinforcement learning;Signal processing;Market research;Stability analysis;Speech proc...
# 304                                          ChatGPT; Generative AI; Large language model (LLM); Stock returns; Weather risk
# 305                                                                                                                     None
# 306                                                                                                                     None
# 307     Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
#
#      Origin
# 0    Scopus
# 1      IEEE
# 2    Scopus
# 3    Scopus
# 4    Scopus
# ..      ...
# 303    IEEE
# 304  Scopus
# 305  Scopus
# 306  Scopus
# 307  Scopus
#
# [308 rows x 6 columns]

# %%
# Set ID as index again
clean_df = clean_df.set_index("ID")
clean_df
# Out:
#                                                                                                                                                                                  Title  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                           A Comparative Study of Sequential Deep Learning Models in Financial Time Series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  A Deep Reinforcement Learning Approach for Portfolio Optimization of Brazilian Assets Using Fundamental and Sentimen...
# 10.1145/3677052.3698649                                                                                                     A Financial Time Series Denoiser Based on Diffusion Models
# 10.3390/jrfm18020099                                                                                                          A First Look at Financial Data Analysis Using ChatGPT-4o
# 10.1007/978-981-19-5845-8_61                                                                                               A Hybrid Approach on Conditional GAN for Portfolio Analysis
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                            Trend-Heuristic Reinforcement Learning Framework for News-Oriented Stock Portfolio Management
# 10.1007/s11156-025-01437-x                                                                                   Using Generative AI to predict the weather impact on future stock returns
# 10.3905/jpm.2025.1.710                                                                                        Using Large Language Models to Estimate Novel Risk: Impact on Volatility
# 10.1038/s41467-025-61292-1                                                                        Utility of synthetic musculoskeletal gaits for generalizable healthcare applications
# 10.1007/s12525-025-00815-6                                                          Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
#
#                                                                                              DOI  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                10.1109/iscmi63661.2024.10851487
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558    10.1109/compsac65507.2025.00258
# 10.1145/3677052.3698649                                                  10.1145/3677052.3698649
# 10.3390/jrfm18020099                                                        10.3390/jrfm18020099
# 10.1007/978-981-19-5845-8_61                                        10.1007/978-981-19-5845-8_61
# ...                                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  10.1109/icassp48485.2024.10447993
# 10.1007/s11156-025-01437-x                                            10.1007/s11156-025-01437-x
# 10.3905/jpm.2025.1.710                                                    10.3905/jpm.2025.1.710
# 10.1038/s41467-025-61292-1                                            10.1038/s41467-025-61292-1
# 10.1007/s12525-025-00815-6                                            10.1007/s12525-025-00815-6
#
#                                                                                                                                                                               Abstract  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Time series analysis of daily stock prices is challenging due to the inherent complexity, nonlinearity, and nonstati...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  The Brazilian capital market presents unique challenges for portfolio optimization due to its volatility and informa...
# 10.1145/3677052.3698649                                        Financial time series often exhibit low signal-to-noise ratio, posing significant challenges for accurate data inter...
# 10.3390/jrfm18020099                                           OpenAI’s new flagship model, ChatGPT-4o, released on 13 May 2024, offers enhanced natural language understanding and...
# 10.1007/978-981-19-5845-8_61                                   Over the decades, the Markowitz framework has been used extensively in portfolio analysis though it puts too much em...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  Recent studies have shown that reinforcement learning (RL) methods have brought significant performance gains for st...
# 10.1007/s11156-025-01437-x                                     This study explores the use of Generative AI, specifically OpenAI’s ChatGPT, for forecasting the impacts of severe w...
# 10.3905/jpm.2025.1.710                                         This article presents an integrated framework to estimate hard to measure (novel) financial risk for volatility fore...
# 10.1038/s41467-025-61292-1                                     Deep-neural-network-based artificial intelligence enables quantitative gait analysis with commodity sensors. However...
# 10.1007/s12525-025-00815-6                                     The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
#
#                                                                                                                                                                               Keywords  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                                         Deep Learning; Finance; Large Language Model; Survey; Time Series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  Training;Sentiment analysis;Soft sensors;Software algorithms;Benchmark testing;Deep reinforcement learning;Performan...
# 10.1145/3677052.3698649                                                                                                     Denoising; Diffusion Model; Financial Time Series; Trading
# 10.3390/jrfm18020099                                           academia; artificial intelligence (AI); ChatGPT; data analysis; finance research; financial analysis; generative AI ...
# 10.1007/978-981-19-5845-8_61                                   Autoencoding conditional GAN (ACGAN); Conditional GAN; Hybrid CGAN; Markowitz framework; Portfolio analysis and allo...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  Training;Supervised learning;Reinforcement learning;Signal processing;Market research;Stability analysis;Speech proc...
# 10.1007/s11156-025-01437-x                                                                             ChatGPT; Generative AI; Large language model (LLM); Stock returns; Weather risk
# 10.3905/jpm.2025.1.710                                                                                                                                                            None
# 10.1038/s41467-025-61292-1                                                                                                                                                        None
# 10.1007/s12525-025-00815-6                                        Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
#
#                                                                Origin
# ID
# 10.1109/ISCMI63661.2024.10851487                               Scopus
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558    IEEE
# 10.1145/3677052.3698649                                        Scopus
# 10.3390/jrfm18020099                                           Scopus
# 10.1007/978-981-19-5845-8_61                                   Scopus
# ...                                                               ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993    IEEE
# 10.1007/s11156-025-01437-x                                     Scopus
# 10.3905/jpm.2025.1.710                                         Scopus
# 10.1038/s41467-025-61292-1                                     Scopus
# 10.1007/s12525-025-00815-6                                     Scopus
#
# [308 rows x 5 columns]

# %%
# Save initial screening as csv file
clean_df.to_csv("initial_screening.csv")

# %% [markdown]
# # 3. GPT Assessment

# %%
# # Merge GPT files
# import pandas as pd

# # Read the two CSV files
# df1 = pd.read_csv("gpt.csv")
# df2 = pd.read_csv("gpt13.csv")

# # Merge (concatenate) the two DataFrames
# merged_df = pd.concat([df1, df2], ignore_index=True)

# # Optionally, drop duplicates if needed
# # merged_df = merged_df.drop_duplicates()

# # Write the merged DataFrame to a new CSV file
# merged_df.to_csv("gpt.csv", index=False)

# duplicate_counts = merged_df["ID"].value_counts()
# num_duplicates = (duplicate_counts > 1).sum()

# print(f"Antall unike ID-er som forekommer mer enn én gang: {num_duplicates}")

# %%
# Load previous assessments
gpt_response_df = pd.read_csv("gpt.csv", index_col=0)
gpt_response_df
# Out:
#                                                                                                                                                                                Summary  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Compares LSTM, Transformer, and LLMs for daily stock prediction; Transformers lead in accuracy, and cleaned LLM outp...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  DRL portfolio optimization for Brazilian assets integrates Gemini-Pro-derived Portuguese news sentiment and fundamen...
# 10.1145/3677052.3698649                                        Uses diffusion models to denoise financial time series, improving downstream return-classification and trading effic...
# 10.3390/jrfm18020099                                           Assesses ChatGPT-4o for financial data analysis tasks (e.g., ARMA-GARCH), finding broadly comparable performance to ...
# 10.1007/978-981-19-5845-8_61                                   Presents HybridCGAN/HybridACGAN for portfolio analysis, learning trends while modeling uncertainty; improves allocat...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  TrendTrader uses an LLM for news sentiment and trend heuristics within an RL portfolio manager to enhance stability ...
# 10.1007/s11156-025-01437-x                                     ChatGPT assesses severe-weather text to forecast stock return impacts; signals improve cross-sectional return predic...
# 10.3905/jpm.2025.1.710                                         LLM-extracted ESG/geopolitical/supply-chain risks with financials in an LSTM improve firm-specific volatility foreca...
# 10.1038/s41467-025-61292-1                                     Generates synthetic musculoskeletal gaits to pre-train models for healthcare gait analysis, improving generalization...
# 10.1007/s12525-025-00815-6                                     Extracts explicit buy/sell ‘crowd’ signals from social media with LLM-based NLP and shows they predict short-term cr...
#
#                                                               LLM?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558   ✔️
# 10.1145/3677052.3698649                                          ❌
# 10.3390/jrfm18020099                                             ❌
# 10.1007/978-981-19-5845-8_61                                     ❌
# ...                                                            ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993   ✔️
# 10.1007/s11156-025-01437-x                                      ✔️
# 10.3905/jpm.2025.1.710                                          ✔️
# 10.1038/s41467-025-61292-1                                       ❌
# 10.1007/s12525-025-00815-6                                      ✔️
#
#                                                               Input enhancement?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                               ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                 ✔️
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                 ✔️
# 10.1007/s11156-025-01437-x                                                    ✔️
# 10.3905/jpm.2025.1.710                                                        ✔️
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                    ✔️
#
#                                                               Prediction engine?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                              ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                  ❌
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                  ❌
# 10.1007/s11156-025-01437-x                                                     ❌
# 10.3905/jpm.2025.1.710                                                         ❌
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                     ❌
#
#                                                               Post-prediction reasoning?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                       ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                         ✔️
# 10.1145/3677052.3698649                                                                ❌
# 10.3390/jrfm18020099                                                                   ❌
# 10.1007/978-981-19-5845-8_61                                                           ❌
# ...                                                                                  ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                         ✔️
# 10.1007/s11156-025-01437-x                                                             ❌
# 10.3905/jpm.2025.1.710                                                                 ❌
# 10.1038/s41467-025-61292-1                                                             ❌
# 10.1007/s12525-025-00815-6                                                             ❌
#
#                                                               Financial instrument?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                 ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                     ❌
# 10.1145/3677052.3698649                                                          ✔️
# 10.3390/jrfm18020099                                                              ❌
# 10.1007/978-981-19-5845-8_61                                                      ❌
# ...                                                                             ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                     ❌
# 10.1007/s11156-025-01437-x                                                       ✔️
# 10.3905/jpm.2025.1.710                                                            ❌
# 10.1038/s41467-025-61292-1                                                        ❌
# 10.1007/s12525-025-00815-6                                                       ✔️
#
#                                                                    Instrument
# ID
# 10.1109/ISCMI63661.2024.10851487                                       Stocks
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558             NaN
# 10.1145/3677052.3698649                                                Stocks
# 10.3390/jrfm18020099                                                        ?
# 10.1007/978-981-19-5845-8_61                                              NaN
# ...                                                                       ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993             NaN
# 10.1007/s11156-025-01437-x                                              Stock
# 10.3905/jpm.2025.1.710                                                      ?
# 10.1038/s41467-025-61292-1                                                  ?
# 10.1007/s12525-025-00815-6                                     Cryptocurrency
#
# [308 rows x 7 columns]

# %%
# Generate prompts to Chat GPT
import os
from IPython.display import clear_output

batch_size = 50
i = 0

# Filter clean df on whether a gpt assessment has already been done
input_df = clean_df.drop(gpt_response_df.index, errors='ignore')[["Title", "Abstract"]]

for batch in range(0, len(input_df), batch_size):
    batch_df = input_df.iloc[batch:batch+batch_size]
    print("""
For the following CSV list of articles, please return a CSV with the following columns:
- "ID": The ID of the article, corresponding to the ID in the provided CSV.
- "Summary": A one-to-two sentence summary of the article
- "LLM?": A column with the value ✔️ if the article actively uses a Large Language Model (e.g., GPT, ChatGPT, Gemini) to improve prediction and ❌ otherwise
- "Input enhancement?": A column with the value ✔️ if an LLM is used pre-prediction for data/feature preparation (e.g., sentiment from text, event extraction, text-to-features) and ❌ otherwise
- "Prediction engine?": A column with the value ✔️ if an LLM itself is the predictive model for a financial target and ❌ otherwise
- "Post-prediction reasoning?": A column with the value ✔️ if an LLM is used after prediction for explanation or decision support (e.g., interpreting model outputs, scenario analysis) and ❌ otherwise
- "Financial instrument?": A column with the value ✔️ if the article contains a model that predicts the price of a financial instrument and ❌ otherwise
- "Instrument": A column with the type of the financial instrument that is predicted
You can also answer "?" to any question if it cannot be answered based on the title or abstract. Please ensure that the CSV is valid by applying quotation marks wherever necessary.
""")
    print(batch_df.to_csv(index=True))
    input("Press enter to get next prompt")
    clear_output(wait=True)

# %% [markdown]
# ### Load Assessments

# %%
# Load all assessments
gpt_response_df = pd.read_csv("gpt.csv", index_col="ID")
gpt_response_df
# Out:
#                                                                                                                                                                                Summary  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Compares LSTM, Transformer, and LLMs for daily stock prediction; Transformers lead in accuracy, and cleaned LLM outp...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  DRL portfolio optimization for Brazilian assets integrates Gemini-Pro-derived Portuguese news sentiment and fundamen...
# 10.1145/3677052.3698649                                        Uses diffusion models to denoise financial time series, improving downstream return-classification and trading effic...
# 10.3390/jrfm18020099                                           Assesses ChatGPT-4o for financial data analysis tasks (e.g., ARMA-GARCH), finding broadly comparable performance to ...
# 10.1007/978-981-19-5845-8_61                                   Presents HybridCGAN/HybridACGAN for portfolio analysis, learning trends while modeling uncertainty; improves allocat...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  TrendTrader uses an LLM for news sentiment and trend heuristics within an RL portfolio manager to enhance stability ...
# 10.1007/s11156-025-01437-x                                     ChatGPT assesses severe-weather text to forecast stock return impacts; signals improve cross-sectional return predic...
# 10.3905/jpm.2025.1.710                                         LLM-extracted ESG/geopolitical/supply-chain risks with financials in an LSTM improve firm-specific volatility foreca...
# 10.1038/s41467-025-61292-1                                     Generates synthetic musculoskeletal gaits to pre-train models for healthcare gait analysis, improving generalization...
# 10.1007/s12525-025-00815-6                                     Extracts explicit buy/sell ‘crowd’ signals from social media with LLM-based NLP and shows they predict short-term cr...
#
#                                                               LLM?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558   ✔️
# 10.1145/3677052.3698649                                          ❌
# 10.3390/jrfm18020099                                             ❌
# 10.1007/978-981-19-5845-8_61                                     ❌
# ...                                                            ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993   ✔️
# 10.1007/s11156-025-01437-x                                      ✔️
# 10.3905/jpm.2025.1.710                                          ✔️
# 10.1038/s41467-025-61292-1                                       ❌
# 10.1007/s12525-025-00815-6                                      ✔️
#
#                                                               Input enhancement?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                               ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                 ✔️
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                 ✔️
# 10.1007/s11156-025-01437-x                                                    ✔️
# 10.3905/jpm.2025.1.710                                                        ✔️
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                    ✔️
#
#                                                               Prediction engine?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                              ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                  ❌
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                  ❌
# 10.1007/s11156-025-01437-x                                                     ❌
# 10.3905/jpm.2025.1.710                                                         ❌
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                     ❌
#
#                                                               Post-prediction reasoning?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                       ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                         ✔️
# 10.1145/3677052.3698649                                                                ❌
# 10.3390/jrfm18020099                                                                   ❌
# 10.1007/978-981-19-5845-8_61                                                           ❌
# ...                                                                                  ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                         ✔️
# 10.1007/s11156-025-01437-x                                                             ❌
# 10.3905/jpm.2025.1.710                                                                 ❌
# 10.1038/s41467-025-61292-1                                                             ❌
# 10.1007/s12525-025-00815-6                                                             ❌
#
#                                                               Financial instrument?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                 ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                     ❌
# 10.1145/3677052.3698649                                                          ✔️
# 10.3390/jrfm18020099                                                              ❌
# 10.1007/978-981-19-5845-8_61                                                      ❌
# ...                                                                             ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                     ❌
# 10.1007/s11156-025-01437-x                                                       ✔️
# 10.3905/jpm.2025.1.710                                                            ❌
# 10.1038/s41467-025-61292-1                                                        ❌
# 10.1007/s12525-025-00815-6                                                       ✔️
#
#                                                                    Instrument
# ID
# 10.1109/ISCMI63661.2024.10851487                                       Stocks
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558             NaN
# 10.1145/3677052.3698649                                                Stocks
# 10.3390/jrfm18020099                                                        ?
# 10.1007/978-981-19-5845-8_61                                              NaN
# ...                                                                       ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993             NaN
# 10.1007/s11156-025-01437-x                                              Stock
# 10.3905/jpm.2025.1.710                                                      ?
# 10.1038/s41467-025-61292-1                                                  ?
# 10.1007/s12525-025-00815-6                                     Cryptocurrency
#
# [308 rows x 7 columns]

# %%
# Remove duplicate indices in gpt_response_df
gpt_response_df = gpt_response_df[~gpt_response_df.index.duplicated(keep='last')]

gpt_response_df
# Out:
#                                                                                                                                                                                Summary  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Compares LSTM, Transformer, and LLMs for daily stock prediction; Transformers lead in accuracy, and cleaned LLM outp...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  DRL portfolio optimization for Brazilian assets integrates Gemini-Pro-derived Portuguese news sentiment and fundamen...
# 10.1145/3677052.3698649                                        Uses diffusion models to denoise financial time series, improving downstream return-classification and trading effic...
# 10.3390/jrfm18020099                                           Assesses ChatGPT-4o for financial data analysis tasks (e.g., ARMA-GARCH), finding broadly comparable performance to ...
# 10.1007/978-981-19-5845-8_61                                   Presents HybridCGAN/HybridACGAN for portfolio analysis, learning trends while modeling uncertainty; improves allocat...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  TrendTrader uses an LLM for news sentiment and trend heuristics within an RL portfolio manager to enhance stability ...
# 10.1007/s11156-025-01437-x                                     ChatGPT assesses severe-weather text to forecast stock return impacts; signals improve cross-sectional return predic...
# 10.3905/jpm.2025.1.710                                         LLM-extracted ESG/geopolitical/supply-chain risks with financials in an LSTM improve firm-specific volatility foreca...
# 10.1038/s41467-025-61292-1                                     Generates synthetic musculoskeletal gaits to pre-train models for healthcare gait analysis, improving generalization...
# 10.1007/s12525-025-00815-6                                     Extracts explicit buy/sell ‘crowd’ signals from social media with LLM-based NLP and shows they predict short-term cr...
#
#                                                               LLM?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558   ✔️
# 10.1145/3677052.3698649                                          ❌
# 10.3390/jrfm18020099                                             ❌
# 10.1007/978-981-19-5845-8_61                                     ❌
# ...                                                            ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993   ✔️
# 10.1007/s11156-025-01437-x                                      ✔️
# 10.3905/jpm.2025.1.710                                          ✔️
# 10.1038/s41467-025-61292-1                                       ❌
# 10.1007/s12525-025-00815-6                                      ✔️
#
#                                                               Input enhancement?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                               ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                 ✔️
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                 ✔️
# 10.1007/s11156-025-01437-x                                                    ✔️
# 10.3905/jpm.2025.1.710                                                        ✔️
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                    ✔️
#
#                                                               Prediction engine?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                              ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                  ❌
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                  ❌
# 10.1007/s11156-025-01437-x                                                     ❌
# 10.3905/jpm.2025.1.710                                                         ❌
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                     ❌
#
#                                                               Post-prediction reasoning?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                       ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                         ✔️
# 10.1145/3677052.3698649                                                                ❌
# 10.3390/jrfm18020099                                                                   ❌
# 10.1007/978-981-19-5845-8_61                                                           ❌
# ...                                                                                  ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                         ✔️
# 10.1007/s11156-025-01437-x                                                             ❌
# 10.3905/jpm.2025.1.710                                                                 ❌
# 10.1038/s41467-025-61292-1                                                             ❌
# 10.1007/s12525-025-00815-6                                                             ❌
#
#                                                               Financial instrument?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                 ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                     ❌
# 10.1145/3677052.3698649                                                          ✔️
# 10.3390/jrfm18020099                                                              ❌
# 10.1007/978-981-19-5845-8_61                                                      ❌
# ...                                                                             ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                     ❌
# 10.1007/s11156-025-01437-x                                                       ✔️
# 10.3905/jpm.2025.1.710                                                            ❌
# 10.1038/s41467-025-61292-1                                                        ❌
# 10.1007/s12525-025-00815-6                                                       ✔️
#
#                                                                    Instrument
# ID
# 10.1109/ISCMI63661.2024.10851487                                       Stocks
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558             NaN
# 10.1145/3677052.3698649                                                Stocks
# 10.3390/jrfm18020099                                                        ?
# 10.1007/978-981-19-5845-8_61                                              NaN
# ...                                                                       ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993             NaN
# 10.1007/s11156-025-01437-x                                              Stock
# 10.3905/jpm.2025.1.710                                                      ?
# 10.1038/s41467-025-61292-1                                                  ?
# 10.1007/s12525-025-00815-6                                     Cryptocurrency
#
# [308 rows x 7 columns]

# %%
processed_df = clean_df.join(gpt_response_df)

processed_df
# Out:
#                                                                                                                                                                                  Title  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                           A Comparative Study of Sequential Deep Learning Models in Financial Time Series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  A Deep Reinforcement Learning Approach for Portfolio Optimization of Brazilian Assets Using Fundamental and Sentimen...
# 10.1145/3677052.3698649                                                                                                     A Financial Time Series Denoiser Based on Diffusion Models
# 10.3390/jrfm18020099                                                                                                          A First Look at Financial Data Analysis Using ChatGPT-4o
# 10.1007/978-981-19-5845-8_61                                                                                               A Hybrid Approach on Conditional GAN for Portfolio Analysis
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                            Trend-Heuristic Reinforcement Learning Framework for News-Oriented Stock Portfolio Management
# 10.1007/s11156-025-01437-x                                                                                   Using Generative AI to predict the weather impact on future stock returns
# 10.3905/jpm.2025.1.710                                                                                        Using Large Language Models to Estimate Novel Risk: Impact on Volatility
# 10.1038/s41467-025-61292-1                                                                        Utility of synthetic musculoskeletal gaits for generalizable healthcare applications
# 10.1007/s12525-025-00815-6                                                          Wisdom of the crowd signals: Predictive power of social media trading signals for cryptocurrencies
#
#                                                                                              DOI  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                10.1109/iscmi63661.2024.10851487
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558    10.1109/compsac65507.2025.00258
# 10.1145/3677052.3698649                                                  10.1145/3677052.3698649
# 10.3390/jrfm18020099                                                        10.3390/jrfm18020099
# 10.1007/978-981-19-5845-8_61                                        10.1007/978-981-19-5845-8_61
# ...                                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  10.1109/icassp48485.2024.10447993
# 10.1007/s11156-025-01437-x                                            10.1007/s11156-025-01437-x
# 10.3905/jpm.2025.1.710                                                    10.3905/jpm.2025.1.710
# 10.1038/s41467-025-61292-1                                            10.1038/s41467-025-61292-1
# 10.1007/s12525-025-00815-6                                            10.1007/s12525-025-00815-6
#
#                                                                                                                                                                               Abstract  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Time series analysis of daily stock prices is challenging due to the inherent complexity, nonlinearity, and nonstati...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  The Brazilian capital market presents unique challenges for portfolio optimization due to its volatility and informa...
# 10.1145/3677052.3698649                                        Financial time series often exhibit low signal-to-noise ratio, posing significant challenges for accurate data inter...
# 10.3390/jrfm18020099                                           OpenAI’s new flagship model, ChatGPT-4o, released on 13 May 2024, offers enhanced natural language understanding and...
# 10.1007/978-981-19-5845-8_61                                   Over the decades, the Markowitz framework has been used extensively in portfolio analysis though it puts too much em...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  Recent studies have shown that reinforcement learning (RL) methods have brought significant performance gains for st...
# 10.1007/s11156-025-01437-x                                     This study explores the use of Generative AI, specifically OpenAI’s ChatGPT, for forecasting the impacts of severe w...
# 10.3905/jpm.2025.1.710                                         This article presents an integrated framework to estimate hard to measure (novel) financial risk for volatility fore...
# 10.1038/s41467-025-61292-1                                     Deep-neural-network-based artificial intelligence enables quantitative gait analysis with commodity sensors. However...
# 10.1007/s12525-025-00815-6                                     The emergence of cryptocurrencies and decentralized finance (DeFi) applications brings unique challenges, including ...
#
#                                                                                                                                                                               Keywords  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                                         Deep Learning; Finance; Large Language Model; Survey; Time Series Forecasting
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  Training;Sentiment analysis;Soft sensors;Software algorithms;Benchmark testing;Deep reinforcement learning;Performan...
# 10.1145/3677052.3698649                                                                                                     Denoising; Diffusion Model; Financial Time Series; Trading
# 10.3390/jrfm18020099                                           academia; artificial intelligence (AI); ChatGPT; data analysis; finance research; financial analysis; generative AI ...
# 10.1007/978-981-19-5845-8_61                                   Autoencoding conditional GAN (ACGAN); Conditional GAN; Hybrid CGAN; Markowitz framework; Portfolio analysis and allo...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  Training;Supervised learning;Reinforcement learning;Signal processing;Market research;Stability analysis;Speech proc...
# 10.1007/s11156-025-01437-x                                                                             ChatGPT; Generative AI; Large language model (LLM); Stock returns; Weather risk
# 10.3905/jpm.2025.1.710                                                                                                                                                            None
# 10.1038/s41467-025-61292-1                                                                                                                                                        None
# 10.1007/s12525-025-00815-6                                        Collective intelligence; Cryptocurrencies; Predictive power; Social media signals; Trading signals; Wisdom of crowds
#
#                                                                Origin  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Scopus
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558    IEEE
# 10.1145/3677052.3698649                                        Scopus
# 10.3390/jrfm18020099                                           Scopus
# 10.1007/978-981-19-5845-8_61                                   Scopus
# ...                                                               ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993    IEEE
# 10.1007/s11156-025-01437-x                                     Scopus
# 10.3905/jpm.2025.1.710                                         Scopus
# 10.1038/s41467-025-61292-1                                     Scopus
# 10.1007/s12525-025-00815-6                                     Scopus
#
#                                                                                                                                                                                Summary  \
# ID
# 10.1109/ISCMI63661.2024.10851487                               Compares LSTM, Transformer, and LLMs for daily stock prediction; Transformers lead in accuracy, and cleaned LLM outp...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558  DRL portfolio optimization for Brazilian assets integrates Gemini-Pro-derived Portuguese news sentiment and fundamen...
# 10.1145/3677052.3698649                                        Uses diffusion models to denoise financial time series, improving downstream return-classification and trading effic...
# 10.3390/jrfm18020099                                           Assesses ChatGPT-4o for financial data analysis tasks (e.g., ARMA-GARCH), finding broadly comparable performance to ...
# 10.1007/978-981-19-5845-8_61                                   Presents HybridCGAN/HybridACGAN for portfolio analysis, learning trends while modeling uncertainty; improves allocat...
# ...                                                                                                                                                                                ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993  TrendTrader uses an LLM for news sentiment and trend heuristics within an RL portfolio manager to enhance stability ...
# 10.1007/s11156-025-01437-x                                     ChatGPT assesses severe-weather text to forecast stock return impacts; signals improve cross-sectional return predic...
# 10.3905/jpm.2025.1.710                                         LLM-extracted ESG/geopolitical/supply-chain risks with financials in an LSTM improve firm-specific volatility foreca...
# 10.1038/s41467-025-61292-1                                     Generates synthetic musculoskeletal gaits to pre-train models for healthcare gait analysis, improving generalization...
# 10.1007/s12525-025-00815-6                                     Extracts explicit buy/sell ‘crowd’ signals from social media with LLM-based NLP and shows they predict short-term cr...
#
#                                                               LLM?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558   ✔️
# 10.1145/3677052.3698649                                          ❌
# 10.3390/jrfm18020099                                             ❌
# 10.1007/978-981-19-5845-8_61                                     ❌
# ...                                                            ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993   ✔️
# 10.1007/s11156-025-01437-x                                      ✔️
# 10.3905/jpm.2025.1.710                                          ✔️
# 10.1038/s41467-025-61292-1                                       ❌
# 10.1007/s12525-025-00815-6                                      ✔️
#
#                                                               Input enhancement?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                               ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                 ✔️
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                 ✔️
# 10.1007/s11156-025-01437-x                                                    ✔️
# 10.3905/jpm.2025.1.710                                                        ✔️
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                    ✔️
#
#                                                               Prediction engine?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                              ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                  ❌
# 10.1145/3677052.3698649                                                        ❌
# 10.3390/jrfm18020099                                                           ❌
# 10.1007/978-981-19-5845-8_61                                                   ❌
# ...                                                                          ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                  ❌
# 10.1007/s11156-025-01437-x                                                     ❌
# 10.3905/jpm.2025.1.710                                                         ❌
# 10.1038/s41467-025-61292-1                                                     ❌
# 10.1007/s12525-025-00815-6                                                     ❌
#
#                                                               Post-prediction reasoning?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                       ❌
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                         ✔️
# 10.1145/3677052.3698649                                                                ❌
# 10.3390/jrfm18020099                                                                   ❌
# 10.1007/978-981-19-5845-8_61                                                           ❌
# ...                                                                                  ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                         ✔️
# 10.1007/s11156-025-01437-x                                                             ❌
# 10.3905/jpm.2025.1.710                                                                 ❌
# 10.1038/s41467-025-61292-1                                                             ❌
# 10.1007/s12525-025-00815-6                                                             ❌
#
#                                                               Financial instrument?  \
# ID
# 10.1109/ISCMI63661.2024.10851487                                                 ✔️
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558                     ❌
# 10.1145/3677052.3698649                                                          ✔️
# 10.3390/jrfm18020099                                                              ❌
# 10.1007/978-981-19-5845-8_61                                                      ❌
# ...                                                                             ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993                     ❌
# 10.1007/s11156-025-01437-x                                                       ✔️
# 10.3905/jpm.2025.1.710                                                            ❌
# 10.1038/s41467-025-61292-1                                                        ❌
# 10.1007/s12525-025-00815-6                                                       ✔️
#
#                                                                    Instrument
# ID
# 10.1109/ISCMI63661.2024.10851487                                       Stocks
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=11126558             NaN
# 10.1145/3677052.3698649                                                Stocks
# 10.3390/jrfm18020099                                                        ?
# 10.1007/978-981-19-5845-8_61                                              NaN
# ...                                                                       ...
# https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=10447993             NaN
# 10.1007/s11156-025-01437-x                                              Stock
# 10.3905/jpm.2025.1.710                                                      ?
# 10.1038/s41467-025-61292-1                                                  ?
# 10.1007/s12525-025-00815-6                                     Cryptocurrency
#
# [308 rows x 12 columns]

# %% [markdown]
# # 4. Make decisions on whether to include articles

# %%
# Load previous decisions
decisions_file_path = "decisions.csv"
decisions_df = pd.read_csv(decisions_file_path, index_col=0)
decisions_df.sort_values("Date", ascending=True)
# Out:
# Empty DataFrame
# Columns: [Decision, Date, Reviewer]
# Index: []

# %%
# Keep own version to mitigate overwriting each other
my_decisions_df = decisions_df.copy()

# %%
from datetime import datetime
from IPython.display import display, HTML, clear_output

reviewer = input("What is your name?")

# Shuffle the indices of the DataFrame to limit chance of two people reviewing the same article at the same time
np.random.seed(hash(reviewer) % 2**32)
shuffled_indices = np.random.permutation(processed_df.index)

def get_progress():
    decided = set(decisions_df.index).intersection(processed_df.index)
    return len(decided) / len(processed_df)

# Loop through the randomized indices
for index in shuffled_indices:
    row = processed_df.loc[index]
    if index in my_decisions_df.index:
        continue
    if index in skipped:
        continue
    if len(row.shape) > 1:
        row = row.iloc[0]
    if pd.isna(row["Summary"]):
        continue
    clear_output(wait=True)
    print(f"Screening progress: {get_progress() * 100:.2f}%")
    display(HTML(f'<h1>{row["Title"]}</h1>'))
    print("ID:", index)
    display(HTML(f'<a href="https://doi.org/{row["DOI"]}" target="_blank">Link</a>'))
    display(HTML(f'<h2>GPT assessment</h2>'))
    display(HTML(f'<p style="font-size:20px;">Financial instrument?: {row["Financial instrument?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">AI?: {row["AI?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">LLM?: {row["LLM?"]}</p>'))
    display(HTML(f'<p style="font-size:20px;">Instrument: {row["Instrument"]}</p>'))
    display(HTML(f'<h2>Summary</h2>'))
    display(HTML(f'<p style="font-size:18px;line-height:30px">{row["Summary"]}</p>'))
    display(HTML(f'<h2>Keywords</h2>'))
    display(HTML(f'<p style="font-size:18px;line-height:30px">{row["Keywords"]}</p>'))
    display(HTML(f'<h2>Abstract</h2>'))
    display(HTML(f'<p style="font-size:16px;line-height:24px">{row["Abstract"]}</p>'))
    decision = None
    while decision not in ["y", "n", "survey", "tja", "skip"]:
        decision = input("\nInclude this article? (y/n/survey/tja/skip):\n").lower()
    if decision == "skip":
        skipped.add(index)
        continue
    # Add decision
    my_decisions_df.loc[index] = [decision, datetime.now().isoformat(), reviewer]
    # Ensure latest version of file
    # mount()
    decisions_df = pd.read_csv(decisions_file_path, index_col=0)
    # Add any entries in my_decisions_df that are not in decisions_df
    decisions_df = pd.concat([decisions_df, my_decisions_df])
    # Remove rows that are strictly equal
    decisions_df = decisions_df.drop_duplicates(keep="last")
    # Save
    decisions_df.to_csv(decisions_file_path)
# Out:
# Screening progress: 0.00%
# <h1>Comparative Investigation of GPT and FinBERT’s Sentiment Analysis Performance in News Across Different Sectors</h1>
# ID: 10.3390/electronics14061090
# <a href="https://doi.org/10.3390/electronics14061090" target="_blank">Link</a>
# <h2>GPT assessment</h2>
# <p style="font-size:20px;">Financial instrument?: ❌</p>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AI?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[267], line 32
#      30 display(HTML(f'<h2>GPT assessment</h2>'))
#      31 display(HTML(f'<p style="font-size:20px;">Financial instrument?: {row["Financial instrument?"]}</p>'))
# ---> 32 display(HTML(f'<p style="font-size:20px;">AI?: {row["AI?"]}</p>'))
#      33 display(HTML(f'<p style="font-size:20px;">LLM?: {row["LLM?"]}</p>'))
#      34 display(HTML(f'<p style="font-size:20px;">Instrument: {row["Instrument"]}</p>'))
#
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File ~/Desktop/Prosjektoppgave/prosjektoppgave/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'AI?'
